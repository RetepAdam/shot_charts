# %%
# %matplotlib inline
import requests
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from bs4 import BeautifulSoup
import time

# %%
url = 'https://stats.nba.com/stats/shotchartdetail?AheadBehind=&CFID=33&CFPARAMS=1996-97&ClutchTime=&Conference=&ContextFilter=&ContextMeasure=FGA&DateFrom=&DateTo=&Division=&EndPeriod=10&EndRange=28800&GROUP_ID=&GameEventID=&GameID=&GameSegment=&GroupID=&GroupMode=&GroupQuantity=5&LastNGames=0&LeagueID=00&Location=&Month=0&OnOff=&OpponentTeamID=0&Outcome=&PORound=0&Period=0&PlayerID=893&PlayerID1=&PlayerID2=&PlayerID3=&PlayerID4=&PlayerID5=&PlayerPosition=&PointDiff=&Position=&RangeType=0&RookieYear=&Season=1996-97&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StartPeriod=1&StartRange=0&StarterBench=&TeamID=0&VsConference=&VsDivision=&VsPlayerID1=&VsPlayerID2=&VsPlayerID3=&VsPlayerID4=&VsPlayerID5=&VsTeamID='
req = requests.get(url, headers={'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'Accept-Encoding':'gzip, deflate, br',
    'Accept-Language':'en-US,en;q=0.5',
    'Connection':'keep-alive',
    'Host':'stats.nba.com',
    'Referer':'https://t.co/JllioiHFaO',
    'Upgrade-Insecure-Requests':'1',
    'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:65.0) Gecko/20100101 Firefox/65.0'}).json()

# %%
shots = []
X = []
y = []

for i in range(len(req['resultSets'][0]['rowSet'])):
    shots.append([req['resultSets'][0]['rowSet'][i][3], req['resultSets'][0]['rowSet'][i][17], req['resultSets'][0]['rowSet'][i][18]])
    X.append(req['resultSets'][0]['rowSet'][i][17])
    y.append(req['resultSets'][0]['rowSet'][i][18])

# %%
X = np.array(X)
y = np.array(y)

# %%
from matplotlib.patches import Circle, Rectangle, Arc

def draw_court(ax=None, color='black', lw=2, outer_lines=False):
    # If an axes object isn't provided to plot onto, just get current one
    if ax is None:
        ax = plt.gca()

    # Create the various parts of an NBA basketball court

    # Create the basketball hoop
    # Diameter of a hoop is 18" so it has a radius of 9", which is a value
    # 7.5 in our coordinate system
    hoop = Circle((0, 0), radius=7.5, linewidth=lw, color=color, fill=False)

    # Create backboard
    backboard = Rectangle((-30, -7.5), 60, -1, linewidth=lw, color=color)

    # The paint
    # Create the outer box 0f the paint, width=16ft, height=19ft
    outer_box = Rectangle((-80, -47.5), 160, 190, linewidth=lw, color=color,
                          fill=False)
    # Create the inner box of the paint, widt=12ft, height=19ft
    inner_box = Rectangle((-60, -47.5), 120, 190, linewidth=lw, color=color,
                          fill=False)

    # Create free throw top arc
    top_free_throw = Arc((0, 142.5), 120, 120, theta1=0, theta2=180,
                         linewidth=lw, color=color, fill=False)
    # Create free throw bottom arc
    bottom_free_throw = Arc((0, 142.5), 120, 120, theta1=180, theta2=0,
                            linewidth=lw, color=color, linestyle='dashed')
    # Restricted Zone, it is an arc with 4ft radius from center of the hoop
    restricted = Arc((0, 0), 80, 80, theta1=0, theta2=180, linewidth=lw,
                     color=color)

    # Three point line
    # Create the side 3pt lines, they are 14ft long before they begin to arc
    corner_three_a = Rectangle((-220, -47.5), 0, 140, linewidth=lw,
                               color=color)
    corner_three_b = Rectangle((220, -47.5), 0, 140, linewidth=lw, color=color)
    # 3pt arc - center of arc will be the hoop, arc is 23'9" away from hoop
    # I just played around with the theta values until they lined up with the 
    # threes
    three_arc = Arc((0, 0), 475, 475, theta1=22, theta2=158, linewidth=lw,
                    color=color)

    # Center Court
    center_outer_arc = Arc((0, 422.5), 120, 120, theta1=180, theta2=0,
                           linewidth=lw, color=color)
    center_inner_arc = Arc((0, 422.5), 40, 40, theta1=180, theta2=0,
                           linewidth=lw, color=color)

    # List of the court elements to be plotted onto the axes
    court_elements = [hoop, backboard, outer_box, inner_box, top_free_throw,
                      bottom_free_throw, restricted, corner_three_a,
                      corner_three_b, three_arc, center_outer_arc,
                      center_inner_arc]

    if outer_lines:
        # Draw the half court line, baseline and side out bound lines
        outer_lines = Rectangle((-250, -47.5), 500, 470, linewidth=lw,
                                color=color, fill=False)
        court_elements.append(outer_lines)

    # Add the court elements onto the axes
    for element in court_elements:
        ax.add_patch(element)

    return ax



plt.figure(figsize=(12,11))
plt.scatter(X, y)
draw_court()
# Adjust plot limits to just fit in half court
plt.xlim(-250,250)
# Descending values along th y axis from bottom to top
# in order to place the hoop by the top of plot
plt.ylim(422.5, -47.5)
# get rid of axis tick labels
# plt.tick_params(labelbottom=False, labelleft=False)
plt.show()

# %%
import numpy as np
import numpy.random
import matplotlib.pyplot as plt
import sphviewer as sph

def myplot(x, y, nb=32, xsize=500, ysize=500):   
    xmin = np.min(x)
    xmax = np.max(x)
    ymin = np.min(y)
    ymax = np.max(y)

    x0 = (xmin+xmax)/2.
    y0 = (ymin+ymax)/2.

    pos = np.zeros([3, len(x)])
    pos[0,:] = x
    pos[1,:] = y
    w = np.ones(len(x))

    P = sph.Particles(pos, w, nb=nb)
    S = sph.Scene(P)
    S.update_camera(r='infinity', x=x0, y=y0, z=0, 
                    xsize=xsize, ysize=ysize)
    R = sph.Render(S)
    R.set_logscale()
    img = R.get_image()
    extent = R.get_extent()
    for i, j in zip(xrange(4), [x0,x0,y0,y0]):
        extent[i] += j
    print(extent)
    return img, extent

fig = plt.figure(1, figsize=(10,10))
ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(223)
ax4 = fig.add_subplot(224)


# Generate some test data
x = np.random.randn(1000)
y = np.random.randn(1000)

#Plotting a regular scatter plot
ax1.plot(x,y,'k.', markersize=5)
ax1.set_xlim(-3,3)
ax1.set_ylim(-3,3)

heatmap_16, extent_16 = myplot(x,y, nb=16)
heatmap_32, extent_32 = myplot(x,y, nb=32)
heatmap_64, extent_64 = myplot(x,y, nb=64)

ax2.imshow(heatmap_16, extent=extent_16, origin='lower', aspect='auto')
ax2.set_title("Smoothing over 16 neighbors")

ax3.imshow(heatmap_32, extent=extent_32, origin='lower', aspect='auto')
ax3.set_title("Smoothing over 32 neighbors")

#Make the heatmap using a smoothing over 64 neighbors
ax4.imshow(heatmap_64, extent=extent_64, origin='lower', aspect='auto')
ax4.set_title("Smoothing over 64 neighbors")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-68-b9b58cb61d8e> in <module>()
#       2 import numpy.random
#       3 import matplotlib.pyplot as plt
# ----> 4 import sphviewer as sph
#       5
#       6 def myplot(x, y, nb=32, xsize=500, ysize=500):
#
# ModuleNotFoundError: No module named 'sphviewer'

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import numpy as np
import time
import re
import json
from selenium import webdriver
from selenium.webdriver.common.by import By

DRIVER = '/Users/peternygaard/anaconda3/lib/python3.6/site-packages/selenium/webdriver/chromedriver'
driver = webdriver.Chrome(DRIVER)
driver.get("https://stats.nba.com/players/traditional/?sort=PLAYER_NAME&dir=-1&Season=1996-97&SeasonType=Regular%20Season&PerMode=Totals")
driver.implicitly_wait(2)
soup_level1 = BeautifulSoup(driver.page_source, 'lxml')
page_1 = soup_level1.find_all('a')[-55:-5]
tags = []
for i in range(len(page_1)):
     tags.append(['1996-97', str(page_1[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level2 = BeautifulSoup(driver.page_source, 'lxml')
page_2 = soup_level2.find_all('a')[-55:-5]
for i in range(len(page_2)):
     tags.append(['1996-97', str(page_2[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level3 = BeautifulSoup(driver.page_source, 'lxml')
page_3 = soup_level3.find_all('a')[-55:-5]
for i in range(len(page_3)):
     tags.append(['1996-97', str(page_3[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level4 = BeautifulSoup(driver.page_source, 'lxml')
page_4 = soup_level4.find_all('a')[-55:-5]
for i in range(len(page_4)):
     tags.append(['1996-97', str(page_4[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level5 = BeautifulSoup(driver.page_source, 'lxml')
page_5 = soup_level5.find_all('a')[-55:-5]
for i in range(len(page_5)):
     tags.append(['1996-97', str(page_5[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level6 = BeautifulSoup(driver.page_source, 'lxml')
page_6 = soup_level6.find_all('a')[-55:-5]
for i in range(len(page_6)):
     tags.append(['1996-97', str(page_6[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level7 = BeautifulSoup(driver.page_source, 'lxml')
page_7 = soup_level7.find_all('a')[-55:-5]
for i in range(len(page_7)):
     tags.append(['1996-97', str(page_7[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level8 = BeautifulSoup(driver.page_source, 'lxml')
page_8 = soup_level8.find_all('a')[-55:-5]
for i in range(len(page_8)):
     tags.append(['1996-97', str(page_8[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level9 = BeautifulSoup(driver.page_source, 'lxml')
page_9 = soup_level9.find_all('a')[-46:-5]
for i in range(len(page_9)):
     tags.append(['1996-97', str(page_9[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
# soup_level10 = BeautifulSoup(driver.page_source, 'lxml')
# page_10 = soup_level10.find_all('a')[-46:-5]
# for i in range(len(page_10)):
#      tags.append(str(page_10[i]).split('/')[2])
driver.quit()

DRIVER = '/Users/peternygaard/anaconda3/lib/python3.6/site-packages/selenium/webdriver/chromedriver'
driver = webdriver.Chrome(DRIVER)
driver.get("https://stats.nba.com/players/traditional/?sort=PLAYER_NAME&dir=-1&Season=1997-98&SeasonType=Regular%20Season&PerMode=Totals")
driver.implicitly_wait(2)
soup_level1 = BeautifulSoup(driver.page_source, 'lxml')
page_1 = soup_level1.find_all('a')[-55:-5]
for i in range(len(page_1)):
     tags.append(['1997-98', str(page_1[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level2 = BeautifulSoup(driver.page_source, 'lxml')
page_2 = soup_level2.find_all('a')[-55:-5]
for i in range(len(page_2)):
     tags.append(['1997-98', str(page_2[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level3 = BeautifulSoup(driver.page_source, 'lxml')
page_3 = soup_level3.find_all('a')[-55:-5]
for i in range(len(page_3)):
     tags.append(['1997-98', str(page_3[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level4 = BeautifulSoup(driver.page_source, 'lxml')
page_4 = soup_level4.find_all('a')[-55:-5]
for i in range(len(page_4)):
     tags.append(['1997-98', str(page_4[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level5 = BeautifulSoup(driver.page_source, 'lxml')
page_5 = soup_level5.find_all('a')[-55:-5]
for i in range(len(page_5)):
     tags.append(['1997-98', str(page_5[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level6 = BeautifulSoup(driver.page_source, 'lxml')
page_6 = soup_level6.find_all('a')[-55:-5]
for i in range(len(page_6)):
     tags.append(['1997-98', str(page_6[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level7 = BeautifulSoup(driver.page_source, 'lxml')
page_7 = soup_level7.find_all('a')[-55:-5]
for i in range(len(page_7)):
     tags.append(['1997-98', str(page_7[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level8 = BeautifulSoup(driver.page_source, 'lxml')
page_8 = soup_level8.find_all('a')[-55:-5]
for i in range(len(page_8)):
     tags.append(['1997-98', str(page_8[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level9 = BeautifulSoup(driver.page_source, 'lxml')
page_9 = soup_level9.find_all('a')[-44:-5]
for i in range(len(page_9)):
     tags.append(['1997-98', str(page_9[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
# soup_level10 = BeautifulSoup(driver.page_source, 'lxml')
# page_10 = soup_level10.find_all('a')[-46:-5]
# for i in range(len(page_10)):
#      tags.append(str(page_10[i]).split('/')[2])
driver.quit()

DRIVER = '/Users/peternygaard/anaconda3/lib/python3.6/site-packages/selenium/webdriver/chromedriver'
driver = webdriver.Chrome(DRIVER)
driver.get("https://stats.nba.com/players/traditional/?sort=PLAYER_NAME&dir=-1&Season=1998-99&SeasonType=Regular%20Season&PerMode=Totals")
driver.implicitly_wait(2)
soup_level1 = BeautifulSoup(driver.page_source, 'lxml')
page_1 = soup_level1.find_all('a')[-55:-5]
for i in range(len(page_1)):
     tags.append(['1998-99', str(page_1[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level2 = BeautifulSoup(driver.page_source, 'lxml')
page_2 = soup_level2.find_all('a')[-55:-5]
for i in range(len(page_2)):
     tags.append(['1998-99', str(page_2[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level3 = BeautifulSoup(driver.page_source, 'lxml')
page_3 = soup_level3.find_all('a')[-55:-5]
for i in range(len(page_3)):
     tags.append(['1998-99', str(page_3[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level4 = BeautifulSoup(driver.page_source, 'lxml')
page_4 = soup_level4.find_all('a')[-55:-5]
for i in range(len(page_4)):
     tags.append(['1998-99', str(page_4[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level5 = BeautifulSoup(driver.page_source, 'lxml')
page_5 = soup_level5.find_all('a')[-55:-5]
for i in range(len(page_5)):
     tags.append(['1998-99', str(page_5[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level6 = BeautifulSoup(driver.page_source, 'lxml')
page_6 = soup_level6.find_all('a')[-55:-5]
for i in range(len(page_6)):
     tags.append(['1998-99', str(page_6[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level7 = BeautifulSoup(driver.page_source, 'lxml')
page_7 = soup_level7.find_all('a')[-55:-5]
for i in range(len(page_7)):
     tags.append(['1998-99', str(page_7[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level8 = BeautifulSoup(driver.page_source, 'lxml')
page_8 = soup_level8.find_all('a')[-55:-5]
for i in range(len(page_8)):
     tags.append(['1998-99', str(page_8[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level9 = BeautifulSoup(driver.page_source, 'lxml')
page_9 = soup_level9.find_all('a')[-44:-5]
for i in range(len(page_9)):
     tags.append(['1998-99', str(page_9[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
driver.quit()

DRIVER = '/Users/peternygaard/anaconda3/lib/python3.6/site-packages/selenium/webdriver/chromedriver'
driver = webdriver.Chrome(DRIVER)
driver.get("https://stats.nba.com/players/traditional/?sort=PLAYER_NAME&dir=-1&Season=1999-00&SeasonType=Regular%20Season&PerMode=Totals")
driver.implicitly_wait(2)
soup_level1 = BeautifulSoup(driver.page_source, 'lxml')
page_1 = soup_level1.find_all('a')[-55:-5]
for i in range(len(page_1)):
     tags.append(['1999-00', str(page_1[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level2 = BeautifulSoup(driver.page_source, 'lxml')
page_2 = soup_level2.find_all('a')[-55:-5]
for i in range(len(page_2)):
     tags.append(['1999-00', str(page_2[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level3 = BeautifulSoup(driver.page_source, 'lxml')
page_3 = soup_level3.find_all('a')[-55:-5]
for i in range(len(page_3)):
     tags.append(['1999-00', str(page_3[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level4 = BeautifulSoup(driver.page_source, 'lxml')
page_4 = soup_level4.find_all('a')[-55:-5]
for i in range(len(page_4)):
     tags.append(['1999-00', str(page_4[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level5 = BeautifulSoup(driver.page_source, 'lxml')
page_5 = soup_level5.find_all('a')[-55:-5]
for i in range(len(page_5)):
     tags.append(['1999-00', str(page_5[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level6 = BeautifulSoup(driver.page_source, 'lxml')
page_6 = soup_level6.find_all('a')[-55:-5]
for i in range(len(page_6)):
     tags.append(['1999-00', str(page_6[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level7 = BeautifulSoup(driver.page_source, 'lxml')
page_7 = soup_level7.find_all('a')[-55:-5]
for i in range(len(page_7)):
     tags.append(['1999-00', str(page_7[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level8 = BeautifulSoup(driver.page_source, 'lxml')
page_8 = soup_level8.find_all('a')[-55:-5]
for i in range(len(page_8)):
     tags.append(['1999-00', str(page_8[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level9 = BeautifulSoup(driver.page_source, 'lxml')
page_9 = soup_level9.find_all('a')[-43:-5]
for i in range(len(page_9)):
     tags.append(['1999-00', str(page_9[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
driver.quit()

DRIVER = '/Users/peternygaard/anaconda3/lib/python3.6/site-packages/selenium/webdriver/chromedriver'
driver = webdriver.Chrome(DRIVER)
driver.get("https://stats.nba.com/players/traditional/?sort=PLAYER_NAME&dir=-1&Season=2000-01&SeasonType=Regular%20Season&PerMode=Totals")
driver.implicitly_wait(2)
soup_level1 = BeautifulSoup(driver.page_source, 'lxml')
page_1 = soup_level1.find_all('a')[-55:-5]
for i in range(len(page_1)):
     tags.append(['2000-01', str(page_1[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level2 = BeautifulSoup(driver.page_source, 'lxml')
page_2 = soup_level2.find_all('a')[-55:-5]
for i in range(len(page_2)):
     tags.append(['2000-01', str(page_2[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level3 = BeautifulSoup(driver.page_source, 'lxml')
page_3 = soup_level3.find_all('a')[-55:-5]
for i in range(len(page_3)):
     tags.append(['2000-01', str(page_3[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level4 = BeautifulSoup(driver.page_source, 'lxml')
page_4 = soup_level4.find_all('a')[-55:-5]
for i in range(len(page_4)):
     tags.append(['2000-01', str(page_4[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level5 = BeautifulSoup(driver.page_source, 'lxml')
page_5 = soup_level5.find_all('a')[-55:-5]
for i in range(len(page_5)):
     tags.append(['2000-01', str(page_5[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level6 = BeautifulSoup(driver.page_source, 'lxml')
page_6 = soup_level6.find_all('a')[-55:-5]
for i in range(len(page_6)):
     tags.append(['2000-01', str(page_6[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level7 = BeautifulSoup(driver.page_source, 'lxml')
page_7 = soup_level7.find_all('a')[-55:-5]
for i in range(len(page_7)):
     tags.append(['2000-01', str(page_7[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level8 = BeautifulSoup(driver.page_source, 'lxml')
page_8 = soup_level8.find_all('a')[-55:-5]
for i in range(len(page_8)):
     tags.append(['2000-01', str(page_8[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level9 = BeautifulSoup(driver.page_source, 'lxml')
page_9 = soup_level9.find_all('a')[-46:-5]
for i in range(len(page_9)):
     tags.append(['2000-01', str(page_9[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
driver.quit()

DRIVER = '/Users/peternygaard/anaconda3/lib/python3.6/site-packages/selenium/webdriver/chromedriver'
driver = webdriver.Chrome(DRIVER)
driver.get("https://stats.nba.com/players/traditional/?sort=PLAYER_NAME&dir=-1&Season=2001-02&SeasonType=Regular%20Season&PerMode=Totals")
driver.implicitly_wait(2)
soup_level1 = BeautifulSoup(driver.page_source, 'lxml')
page_1 = soup_level1.find_all('a')[-55:-5]
for i in range(len(page_1)):
     tags.append(['2001-02', str(page_1[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level2 = BeautifulSoup(driver.page_source, 'lxml')
page_2 = soup_level2.find_all('a')[-55:-5]
for i in range(len(page_2)):
     tags.append(['2001-02', str(page_2[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level3 = BeautifulSoup(driver.page_source, 'lxml')
page_3 = soup_level3.find_all('a')[-55:-5]
for i in range(len(page_3)):
     tags.append(['2001-02', str(page_3[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level4 = BeautifulSoup(driver.page_source, 'lxml')
page_4 = soup_level4.find_all('a')[-55:-5]
for i in range(len(page_4)):
     tags.append(['2001-02', str(page_4[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level5 = BeautifulSoup(driver.page_source, 'lxml')
page_5 = soup_level5.find_all('a')[-55:-5]
for i in range(len(page_5)):
     tags.append(['2001-02', str(page_5[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level6 = BeautifulSoup(driver.page_source, 'lxml')
page_6 = soup_level6.find_all('a')[-55:-5]
for i in range(len(page_6)):
     tags.append(['2001-02', str(page_6[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level7 = BeautifulSoup(driver.page_source, 'lxml')
page_7 = soup_level7.find_all('a')[-55:-5]
for i in range(len(page_7)):
     tags.append(['2001-02', str(page_7[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level8 = BeautifulSoup(driver.page_source, 'lxml')
page_8 = soup_level8.find_all('a')[-55:-5]
for i in range(len(page_8)):
     tags.append(['2001-02', str(page_8[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level9 = BeautifulSoup(driver.page_source, 'lxml')
page_9 = soup_level9.find_all('a')[-45:-5]
for i in range(len(page_9)):
     tags.append(['2001-02', str(page_9[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
driver.quit()

DRIVER = '/Users/peternygaard/anaconda3/lib/python3.6/site-packages/selenium/webdriver/chromedriver'
driver = webdriver.Chrome(DRIVER)
driver.get("https://stats.nba.com/players/traditional/?sort=PLAYER_NAME&dir=-1&Season=2002-03&SeasonType=Regular%20Season&PerMode=Totals")
driver.implicitly_wait(2)
soup_level1 = BeautifulSoup(driver.page_source, 'lxml')
page_1 = soup_level1.find_all('a')[-55:-5]
for i in range(len(page_1)):
     tags.append(['2002-03', str(page_1[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level2 = BeautifulSoup(driver.page_source, 'lxml')
page_2 = soup_level2.find_all('a')[-55:-5]
for i in range(len(page_2)):
     tags.append(['2002-03', str(page_2[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level3 = BeautifulSoup(driver.page_source, 'lxml')
page_3 = soup_level3.find_all('a')[-55:-5]
for i in range(len(page_3)):
     tags.append(['2002-03', str(page_3[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level4 = BeautifulSoup(driver.page_source, 'lxml')
page_4 = soup_level4.find_all('a')[-55:-5]
for i in range(len(page_4)):
     tags.append(['2002-03', str(page_4[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level5 = BeautifulSoup(driver.page_source, 'lxml')
page_5 = soup_level5.find_all('a')[-55:-5]
for i in range(len(page_5)):
     tags.append(['2002-03', str(page_5[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level6 = BeautifulSoup(driver.page_source, 'lxml')
page_6 = soup_level6.find_all('a')[-55:-5]
for i in range(len(page_6)):
     tags.append(['2002-03', str(page_6[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level7 = BeautifulSoup(driver.page_source, 'lxml')
page_7 = soup_level7.find_all('a')[-55:-5]
for i in range(len(page_7)):
     tags.append(['2002-03', str(page_7[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level8 = BeautifulSoup(driver.page_source, 'lxml')
page_8 = soup_level8.find_all('a')[-55:-5]
for i in range(len(page_8)):
     tags.append(['2002-03', str(page_8[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level9 = BeautifulSoup(driver.page_source, 'lxml')
page_9 = soup_level9.find_all('a')[-33:-5]
for i in range(len(page_9)):
     tags.append(['2002-03', str(page_9[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
driver.quit()

DRIVER = '/Users/peternygaard/anaconda3/lib/python3.6/site-packages/selenium/webdriver/chromedriver'
driver = webdriver.Chrome(DRIVER)
driver.get("https://stats.nba.com/players/traditional/?sort=PLAYER_NAME&dir=-1&Season=2003-04&SeasonType=Regular%20Season&PerMode=Totals")
driver.implicitly_wait(2)
soup_level1 = BeautifulSoup(driver.page_source, 'lxml')
page_1 = soup_level1.find_all('a')[-55:-5]
for i in range(len(page_1)):
     tags.append(['2003-04', str(page_1[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level2 = BeautifulSoup(driver.page_source, 'lxml')
page_2 = soup_level2.find_all('a')[-55:-5]
for i in range(len(page_2)):
     tags.append(['2003-04', str(page_2[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level3 = BeautifulSoup(driver.page_source, 'lxml')
page_3 = soup_level3.find_all('a')[-55:-5]
for i in range(len(page_3)):
     tags.append(['2003-04', str(page_3[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level4 = BeautifulSoup(driver.page_source, 'lxml')
page_4 = soup_level4.find_all('a')[-55:-5]
for i in range(len(page_4)):
     tags.append(['2003-04', str(page_4[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level5 = BeautifulSoup(driver.page_source, 'lxml')
page_5 = soup_level5.find_all('a')[-55:-5]
for i in range(len(page_5)):
     tags.append(['2003-04', str(page_5[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level6 = BeautifulSoup(driver.page_source, 'lxml')
page_6 = soup_level6.find_all('a')[-55:-5]
for i in range(len(page_6)):
     tags.append(['2003-04', str(page_6[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level7 = BeautifulSoup(driver.page_source, 'lxml')
page_7 = soup_level7.find_all('a')[-55:-5]
for i in range(len(page_7)):
     tags.append(['2003-04', str(page_7[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level8 = BeautifulSoup(driver.page_source, 'lxml')
page_8 = soup_level8.find_all('a')[-55:-5]
for i in range(len(page_8)):
     tags.append(['2003-04', str(page_8[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level9 = BeautifulSoup(driver.page_source, 'lxml')
page_9 = soup_level9.find_all('a')[-47:-5]
for i in range(len(page_9)):
     tags.append(['2003-04', str(page_9[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
driver.quit()

DRIVER = '/Users/peternygaard/anaconda3/lib/python3.6/site-packages/selenium/webdriver/chromedriver'
driver = webdriver.Chrome(DRIVER)
driver.get("https://stats.nba.com/players/traditional/?sort=PLAYER_NAME&dir=-1&Season=2004-05&SeasonType=Regular%20Season&PerMode=Totals")
driver.implicitly_wait(2)
soup_level1 = BeautifulSoup(driver.page_source, 'lxml')
page_1 = soup_level1.find_all('a')[-55:-5]
for i in range(len(page_1)):
     tags.append(['2004-05', str(page_1[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level2 = BeautifulSoup(driver.page_source, 'lxml')
page_2 = soup_level2.find_all('a')[-55:-5]
for i in range(len(page_2)):
     tags.append(['2004-05', str(page_2[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level3 = BeautifulSoup(driver.page_source, 'lxml')
page_3 = soup_level3.find_all('a')[-55:-5]
for i in range(len(page_3)):
     tags.append(['2004-05', str(page_3[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level4 = BeautifulSoup(driver.page_source, 'lxml')
page_4 = soup_level4.find_all('a')[-55:-5]
for i in range(len(page_4)):
     tags.append(['2004-05', str(page_4[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level5 = BeautifulSoup(driver.page_source, 'lxml')
page_5 = soup_level5.find_all('a')[-55:-5]
for i in range(len(page_5)):
     tags.append(['2004-05', str(page_5[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level6 = BeautifulSoup(driver.page_source, 'lxml')
page_6 = soup_level6.find_all('a')[-55:-5]
for i in range(len(page_6)):
     tags.append(['2004-05', str(page_6[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level7 = BeautifulSoup(driver.page_source, 'lxml')
page_7 = soup_level7.find_all('a')[-55:-5]
for i in range(len(page_7)):
     tags.append(['2004-05', str(page_7[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level8 = BeautifulSoup(driver.page_source, 'lxml')
page_8 = soup_level8.find_all('a')[-55:-5]
for i in range(len(page_8)):
     tags.append(['2004-05', str(page_8[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level9 = BeautifulSoup(driver.page_source, 'lxml')
page_9 = soup_level9.find_all('a')[-55:-5]
for i in range(len(page_9)):
     tags.append(['2004-05', str(page_9[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level10 = BeautifulSoup(driver.page_source, 'lxml')
page_10 = soup_level10.find_all('a')[-19:-5]
for i in range(len(page_10)):
     tags.append(['2004-05', str(page_10[i]).split('/')[2]])
driver.quit()

DRIVER = '/Users/peternygaard/anaconda3/lib/python3.6/site-packages/selenium/webdriver/chromedriver'
driver = webdriver.Chrome(DRIVER)
driver.get("https://stats.nba.com/players/traditional/?sort=PLAYER_NAME&dir=-1&Season=2005-06&SeasonType=Regular%20Season&PerMode=Totals")
driver.implicitly_wait(2)
soup_level1 = BeautifulSoup(driver.page_source, 'lxml')
page_1 = soup_level1.find_all('a')[-55:-5]
for i in range(len(page_1)):
     tags.append(['2005-06', str(page_1[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level2 = BeautifulSoup(driver.page_source, 'lxml')
page_2 = soup_level2.find_all('a')[-55:-5]
for i in range(len(page_2)):
     tags.append(['2005-06', str(page_2[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level3 = BeautifulSoup(driver.page_source, 'lxml')
page_3 = soup_level3.find_all('a')[-55:-5]
for i in range(len(page_3)):
     tags.append(['2005-06', str(page_3[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level4 = BeautifulSoup(driver.page_source, 'lxml')
page_4 = soup_level4.find_all('a')[-55:-5]
for i in range(len(page_4)):
     tags.append(['2005-06', str(page_4[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level5 = BeautifulSoup(driver.page_source, 'lxml')
page_5 = soup_level5.find_all('a')[-55:-5]
for i in range(len(page_5)):
     tags.append(['2005-06', str(page_5[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level6 = BeautifulSoup(driver.page_source, 'lxml')
page_6 = soup_level6.find_all('a')[-55:-5]
for i in range(len(page_6)):
     tags.append(['2005-06', str(page_6[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level7 = BeautifulSoup(driver.page_source, 'lxml')
page_7 = soup_level7.find_all('a')[-55:-5]
for i in range(len(page_7)):
     tags.append(['2005-06', str(page_7[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level8 = BeautifulSoup(driver.page_source, 'lxml')
page_8 = soup_level8.find_all('a')[-55:-5]
for i in range(len(page_8)):
     tags.append(['2005-06', str(page_8[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level9 = BeautifulSoup(driver.page_source, 'lxml')
page_9 = soup_level9.find_all('a')[-55:-5]
for i in range(len(page_9)):
     tags.append(['2005-06', str(page_9[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level10 = BeautifulSoup(driver.page_source, 'lxml')
page_10 = soup_level10.find_all('a')[-13:-5]
for i in range(len(page_10)):
     tags.append(['2005-06', str(page_10[i]).split('/')[2]])
driver.quit()

DRIVER = '/Users/peternygaard/anaconda3/lib/python3.6/site-packages/selenium/webdriver/chromedriver'
driver = webdriver.Chrome(DRIVER)
driver.get("https://stats.nba.com/players/traditional/?sort=PLAYER_NAME&dir=-1&Season=2006-07&SeasonType=Regular%20Season&PerMode=Totals")
driver.implicitly_wait(2)
soup_level1 = BeautifulSoup(driver.page_source, 'lxml')
page_1 = soup_level1.find_all('a')[-55:-5]
for i in range(len(page_1)):
     tags.append(['2006-07', str(page_1[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level2 = BeautifulSoup(driver.page_source, 'lxml')
page_2 = soup_level2.find_all('a')[-55:-5]
for i in range(len(page_2)):
     tags.append(['2006-07', str(page_2[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level3 = BeautifulSoup(driver.page_source, 'lxml')
page_3 = soup_level3.find_all('a')[-55:-5]
for i in range(len(page_3)):
     tags.append(['2006-07', str(page_3[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level4 = BeautifulSoup(driver.page_source, 'lxml')
page_4 = soup_level4.find_all('a')[-55:-5]
for i in range(len(page_4)):
     tags.append(['2006-07', str(page_4[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level5 = BeautifulSoup(driver.page_source, 'lxml')
page_5 = soup_level5.find_all('a')[-55:-5]
for i in range(len(page_5)):
     tags.append(['2006-07', str(page_5[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level6 = BeautifulSoup(driver.page_source, 'lxml')
page_6 = soup_level6.find_all('a')[-55:-5]
for i in range(len(page_6)):
     tags.append(['2006-07', str(page_6[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level7 = BeautifulSoup(driver.page_source, 'lxml')
page_7 = soup_level7.find_all('a')[-55:-5]
for i in range(len(page_7)):
     tags.append(['2006-07', str(page_7[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level8 = BeautifulSoup(driver.page_source, 'lxml')
page_8 = soup_level8.find_all('a')[-55:-5]
for i in range(len(page_8)):
     tags.append(['2006-07', str(page_8[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level9 = BeautifulSoup(driver.page_source, 'lxml')
page_9 = soup_level9.find_all('a')[-55:-5]
for i in range(len(page_9)):
     tags.append(['2006-07', str(page_9[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level10 = BeautifulSoup(driver.page_source, 'lxml')
page_10 = soup_level10.find_all('a')[-13:-5]
for i in range(len(page_10)):
     tags.append(['2006-07', str(page_10[i]).split('/')[2]])
driver.quit()

DRIVER = '/Users/peternygaard/anaconda3/lib/python3.6/site-packages/selenium/webdriver/chromedriver'
driver = webdriver.Chrome(DRIVER)
driver.get("https://stats.nba.com/players/traditional/?sort=PLAYER_NAME&dir=-1&Season=2007-08&SeasonType=Regular%20Season&PerMode=Totals")
driver.implicitly_wait(2)
soup_level1 = BeautifulSoup(driver.page_source, 'lxml')
page_1 = soup_level1.find_all('a')[-55:-5]
for i in range(len(page_1)):
     tags.append(['2007-08', str(page_1[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level2 = BeautifulSoup(driver.page_source, 'lxml')
page_2 = soup_level2.find_all('a')[-55:-5]
for i in range(len(page_2)):
     tags.append(['2007-08', str(page_2[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level3 = BeautifulSoup(driver.page_source, 'lxml')
page_3 = soup_level3.find_all('a')[-55:-5]
for i in range(len(page_3)):
     tags.append(['2007-08', str(page_3[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level4 = BeautifulSoup(driver.page_source, 'lxml')
page_4 = soup_level4.find_all('a')[-55:-5]
for i in range(len(page_4)):
     tags.append(['2007-08', str(page_4[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level5 = BeautifulSoup(driver.page_source, 'lxml')
page_5 = soup_level5.find_all('a')[-55:-5]
for i in range(len(page_5)):
     tags.append(['2007-08', str(page_5[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level6 = BeautifulSoup(driver.page_source, 'lxml')
page_6 = soup_level6.find_all('a')[-55:-5]
for i in range(len(page_6)):
     tags.append(['2007-08', str(page_6[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level7 = BeautifulSoup(driver.page_source, 'lxml')
page_7 = soup_level7.find_all('a')[-55:-5]
for i in range(len(page_7)):
     tags.append(['2007-08', str(page_7[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level8 = BeautifulSoup(driver.page_source, 'lxml')
page_8 = soup_level8.find_all('a')[-55:-5]
for i in range(len(page_8)):
     tags.append(['2007-08', str(page_8[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level9 = BeautifulSoup(driver.page_source, 'lxml')
page_9 = soup_level9.find_all('a')[-55:-5]
for i in range(len(page_9)):
     tags.append(['2007-08', str(page_9[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level10 = BeautifulSoup(driver.page_source, 'lxml')
page_10 = soup_level10.find_all('a')[-6:-5]
for i in range(len(page_10)):
     tags.append(['2007-08', str(page_10[i]).split('/')[2]])
driver.quit()

DRIVER = '/Users/peternygaard/anaconda3/lib/python3.6/site-packages/selenium/webdriver/chromedriver'
driver = webdriver.Chrome(DRIVER)
driver.get("https://stats.nba.com/players/traditional/?sort=PLAYER_NAME&dir=-1&Season=2008-09&SeasonType=Regular%20Season&PerMode=Totals")
driver.implicitly_wait(2)
soup_level1 = BeautifulSoup(driver.page_source, 'lxml')
page_1 = soup_level1.find_all('a')[-55:-5]
for i in range(len(page_1)):
     tags.append(['2008-09', str(page_1[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level2 = BeautifulSoup(driver.page_source, 'lxml')
page_2 = soup_level2.find_all('a')[-55:-5]
for i in range(len(page_2)):
     tags.append(['2008-09', str(page_2[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level3 = BeautifulSoup(driver.page_source, 'lxml')
page_3 = soup_level3.find_all('a')[-55:-5]
for i in range(len(page_3)):
     tags.append(['2008-09', str(page_3[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level4 = BeautifulSoup(driver.page_source, 'lxml')
page_4 = soup_level4.find_all('a')[-55:-5]
for i in range(len(page_4)):
     tags.append(['2008-09', str(page_4[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level5 = BeautifulSoup(driver.page_source, 'lxml')
page_5 = soup_level5.find_all('a')[-55:-5]
for i in range(len(page_5)):
     tags.append(['2008-09', str(page_5[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level6 = BeautifulSoup(driver.page_source, 'lxml')
page_6 = soup_level6.find_all('a')[-55:-5]
for i in range(len(page_6)):
     tags.append(['2008-09', str(page_6[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level7 = BeautifulSoup(driver.page_source, 'lxml')
page_7 = soup_level7.find_all('a')[-55:-5]
for i in range(len(page_7)):
     tags.append(['2008-09', str(page_7[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level8 = BeautifulSoup(driver.page_source, 'lxml')
page_8 = soup_level8.find_all('a')[-55:-5]
for i in range(len(page_8)):
     tags.append(['2008-09', str(page_8[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level9 = BeautifulSoup(driver.page_source, 'lxml')
page_9 = soup_level9.find_all('a')[-50:-5]
for i in range(len(page_9)):
     tags.append(['2008-09', str(page_9[i]).split('/')[2]])
driver.quit()

DRIVER = '/Users/peternygaard/anaconda3/lib/python3.6/site-packages/selenium/webdriver/chromedriver'
driver = webdriver.Chrome(DRIVER)
driver.get("https://stats.nba.com/players/traditional/?sort=PLAYER_NAME&dir=-1&Season=2009-10&SeasonType=Regular%20Season&PerMode=Totals")
driver.implicitly_wait(2)
soup_level1 = BeautifulSoup(driver.page_source, 'lxml')
page_1 = soup_level1.find_all('a')[-55:-5]
for i in range(len(page_1)):
     tags.append(['2009-10', str(page_1[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level2 = BeautifulSoup(driver.page_source, 'lxml')
page_2 = soup_level2.find_all('a')[-55:-5]
for i in range(len(page_2)):
     tags.append(['2009-10', str(page_2[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level3 = BeautifulSoup(driver.page_source, 'lxml')
page_3 = soup_level3.find_all('a')[-55:-5]
for i in range(len(page_3)):
     tags.append(['2009-10', str(page_3[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level4 = BeautifulSoup(driver.page_source, 'lxml')
page_4 = soup_level4.find_all('a')[-55:-5]
for i in range(len(page_4)):
     tags.append(['2009-10', str(page_4[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level5 = BeautifulSoup(driver.page_source, 'lxml')
page_5 = soup_level5.find_all('a')[-55:-5]
for i in range(len(page_5)):
     tags.append(['2009-10', str(page_5[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level6 = BeautifulSoup(driver.page_source, 'lxml')
page_6 = soup_level6.find_all('a')[-55:-5]
for i in range(len(page_6)):
     tags.append(['2009-10', str(page_6[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level7 = BeautifulSoup(driver.page_source, 'lxml')
page_7 = soup_level7.find_all('a')[-55:-5]
for i in range(len(page_7)):
     tags.append(['2009-10', str(page_7[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level8 = BeautifulSoup(driver.page_source, 'lxml')
page_8 = soup_level8.find_all('a')[-55:-5]
for i in range(len(page_8)):
     tags.append(['2009-10', str(page_8[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level9 = BeautifulSoup(driver.page_source, 'lxml')
page_9 = soup_level9.find_all('a')[-47:-5]
for i in range(len(page_9)):
     tags.append(['2009-10', str(page_9[i]).split('/')[2]])
driver.quit()

DRIVER = '/Users/peternygaard/anaconda3/lib/python3.6/site-packages/selenium/webdriver/chromedriver'
driver = webdriver.Chrome(DRIVER)
driver.get("https://stats.nba.com/players/traditional/?sort=PLAYER_NAME&dir=-1&Season=2010-11&SeasonType=Regular%20Season&PerMode=Totals")
driver.implicitly_wait(2)
soup_level1 = BeautifulSoup(driver.page_source, 'lxml')
page_1 = soup_level1.find_all('a')[-55:-5]
for i in range(len(page_1)):
     tags.append(['2010-11', str(page_1[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level2 = BeautifulSoup(driver.page_source, 'lxml')
page_2 = soup_level2.find_all('a')[-55:-5]
for i in range(len(page_2)):
     tags.append(['2010-11', str(page_2[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level3 = BeautifulSoup(driver.page_source, 'lxml')
page_3 = soup_level3.find_all('a')[-55:-5]
for i in range(len(page_3)):
     tags.append(['2010-11', str(page_3[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level4 = BeautifulSoup(driver.page_source, 'lxml')
page_4 = soup_level4.find_all('a')[-55:-5]
for i in range(len(page_4)):
     tags.append(['2010-11', str(page_4[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level5 = BeautifulSoup(driver.page_source, 'lxml')
page_5 = soup_level5.find_all('a')[-55:-5]
for i in range(len(page_5)):
     tags.append(['2010-11', str(page_5[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level6 = BeautifulSoup(driver.page_source, 'lxml')
page_6 = soup_level6.find_all('a')[-55:-5]
for i in range(len(page_6)):
     tags.append(['2010-11', str(page_6[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level7 = BeautifulSoup(driver.page_source, 'lxml')
page_7 = soup_level7.find_all('a')[-55:-5]
for i in range(len(page_7)):
     tags.append(['2010-11', str(page_7[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level8 = BeautifulSoup(driver.page_source, 'lxml')
page_8 = soup_level8.find_all('a')[-55:-5]
for i in range(len(page_8)):
     tags.append(['2010-11', str(page_8[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level9 = BeautifulSoup(driver.page_source, 'lxml')
page_9 = soup_level9.find_all('a')[-55:-5]
for i in range(len(page_9)):
     tags.append(['2010-11', str(page_9[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level10 = BeautifulSoup(driver.page_source, 'lxml')
page_10 = soup_level10.find_all('a')[-7:-5]
for i in range(len(page_10)):
     tags.append(['2010-11', str(page_10[i]).split('/')[2]])
driver.quit()

DRIVER = '/Users/peternygaard/anaconda3/lib/python3.6/site-packages/selenium/webdriver/chromedriver'
driver = webdriver.Chrome(DRIVER)
driver.get("https://stats.nba.com/players/traditional/?sort=PLAYER_NAME&dir=-1&Season=2011-12&SeasonType=Regular%20Season&PerMode=Totals")
driver.implicitly_wait(2)
soup_level1 = BeautifulSoup(driver.page_source, 'lxml')
page_1 = soup_level1.find_all('a')[-55:-5]
for i in range(len(page_1)):
     tags.append(['2011-12', str(page_1[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level2 = BeautifulSoup(driver.page_source, 'lxml')
page_2 = soup_level2.find_all('a')[-55:-5]
for i in range(len(page_2)):
     tags.append(['2011-12', str(page_2[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level3 = BeautifulSoup(driver.page_source, 'lxml')
page_3 = soup_level3.find_all('a')[-55:-5]
for i in range(len(page_3)):
     tags.append(['2011-12', str(page_3[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level4 = BeautifulSoup(driver.page_source, 'lxml')
page_4 = soup_level4.find_all('a')[-55:-5]
for i in range(len(page_4)):
     tags.append(['2011-12', str(page_4[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level5 = BeautifulSoup(driver.page_source, 'lxml')
page_5 = soup_level5.find_all('a')[-55:-5]
for i in range(len(page_5)):
     tags.append(['2011-12', str(page_5[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level6 = BeautifulSoup(driver.page_source, 'lxml')
page_6 = soup_level6.find_all('a')[-55:-5]
for i in range(len(page_6)):
     tags.append(['2011-12', str(page_6[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level7 = BeautifulSoup(driver.page_source, 'lxml')
page_7 = soup_level7.find_all('a')[-55:-5]
for i in range(len(page_7)):
     tags.append(['2011-12', str(page_7[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level8 = BeautifulSoup(driver.page_source, 'lxml')
page_8 = soup_level8.find_all('a')[-55:-5]
for i in range(len(page_8)):
     tags.append(['2011-12', str(page_8[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level9 = BeautifulSoup(driver.page_source, 'lxml')
page_9 = soup_level9.find_all('a')[-55:-5]
for i in range(len(page_9)):
     tags.append(['2011-12', str(page_9[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level10 = BeautifulSoup(driver.page_source, 'lxml')
page_10 = soup_level10.find_all('a')[-33:-5]
for i in range(len(page_10)):
     tags.append(['2011-12', str(page_10[i]).split('/')[2]])
driver.quit()

DRIVER = '/Users/peternygaard/anaconda3/lib/python3.6/site-packages/selenium/webdriver/chromedriver'
driver = webdriver.Chrome(DRIVER)
driver.get("https://stats.nba.com/players/traditional/?sort=PLAYER_NAME&dir=-1&Season=2012-13&SeasonType=Regular%20Season&PerMode=Totals")
driver.implicitly_wait(2)
soup_level1 = BeautifulSoup(driver.page_source, 'lxml')
page_1 = soup_level1.find_all('a')[-55:-5]
for i in range(len(page_1)):
     tags.append(['2012-13', str(page_1[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level2 = BeautifulSoup(driver.page_source, 'lxml')
page_2 = soup_level2.find_all('a')[-55:-5]
for i in range(len(page_2)):
     tags.append(['2012-13', str(page_2[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level3 = BeautifulSoup(driver.page_source, 'lxml')
page_3 = soup_level3.find_all('a')[-55:-5]
for i in range(len(page_3)):
     tags.append(['2012-13', str(page_3[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level4 = BeautifulSoup(driver.page_source, 'lxml')
page_4 = soup_level4.find_all('a')[-55:-5]
for i in range(len(page_4)):
     tags.append(['2012-13', str(page_4[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level5 = BeautifulSoup(driver.page_source, 'lxml')
page_5 = soup_level5.find_all('a')[-55:-5]
for i in range(len(page_5)):
     tags.append(['2012-13', str(page_5[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level6 = BeautifulSoup(driver.page_source, 'lxml')
page_6 = soup_level6.find_all('a')[-55:-5]
for i in range(len(page_6)):
     tags.append(['2012-13', str(page_6[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level7 = BeautifulSoup(driver.page_source, 'lxml')
page_7 = soup_level7.find_all('a')[-55:-5]
for i in range(len(page_7)):
     tags.append(['2012-13', str(page_7[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level8 = BeautifulSoup(driver.page_source, 'lxml')
page_8 = soup_level8.find_all('a')[-55:-5]
for i in range(len(page_8)):
     tags.append(['2012-13', str(page_8[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level9 = BeautifulSoup(driver.page_source, 'lxml')
page_9 = soup_level9.find_all('a')[-55:-5]
for i in range(len(page_9)):
     tags.append(['2012-13', str(page_9[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level10 = BeautifulSoup(driver.page_source, 'lxml')
page_10 = soup_level10.find_all('a')[-24:-5]
for i in range(len(page_10)):
     tags.append(['2012-13', str(page_10[i]).split('/')[2]])
driver.quit()

DRIVER = '/Users/peternygaard/anaconda3/lib/python3.6/site-packages/selenium/webdriver/chromedriver'
driver = webdriver.Chrome(DRIVER)
driver.get("https://stats.nba.com/players/traditional/?sort=PLAYER_NAME&dir=-1&Season=2013-14&SeasonType=Regular%20Season&PerMode=Totals")
driver.implicitly_wait(2)
soup_level1 = BeautifulSoup(driver.page_source, 'lxml')
page_1 = soup_level1.find_all('a')[-55:-5]
for i in range(len(page_1)):
     tags.append(['2013-14', str(page_1[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level2 = BeautifulSoup(driver.page_source, 'lxml')
page_2 = soup_level2.find_all('a')[-55:-5]
for i in range(len(page_2)):
     tags.append(['2013-14', str(page_2[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level3 = BeautifulSoup(driver.page_source, 'lxml')
page_3 = soup_level3.find_all('a')[-55:-5]
for i in range(len(page_3)):
     tags.append(['2013-14', str(page_3[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level4 = BeautifulSoup(driver.page_source, 'lxml')
page_4 = soup_level4.find_all('a')[-55:-5]
for i in range(len(page_4)):
     tags.append(['2013-14', str(page_4[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level5 = BeautifulSoup(driver.page_source, 'lxml')
page_5 = soup_level5.find_all('a')[-55:-5]
for i in range(len(page_5)):
     tags.append(['2013-14', str(page_5[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level6 = BeautifulSoup(driver.page_source, 'lxml')
page_6 = soup_level6.find_all('a')[-55:-5]
for i in range(len(page_6)):
     tags.append(['2013-14', str(page_6[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level7 = BeautifulSoup(driver.page_source, 'lxml')
page_7 = soup_level7.find_all('a')[-55:-5]
for i in range(len(page_7)):
     tags.append(['2013-14', str(page_7[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level8 = BeautifulSoup(driver.page_source, 'lxml')
page_8 = soup_level8.find_all('a')[-55:-5]
for i in range(len(page_8)):
     tags.append(['2013-14', str(page_8[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level9 = BeautifulSoup(driver.page_source, 'lxml')
page_9 = soup_level9.find_all('a')[-55:-5]
for i in range(len(page_9)):
     tags.append(['2013-14', str(page_9[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level10 = BeautifulSoup(driver.page_source, 'lxml')
page_10 = soup_level10.find_all('a')[-37:-5]
for i in range(len(page_10)):
     tags.append(['2013-14', str(page_10[i]).split('/')[2]])
driver.quit()

DRIVER = '/Users/peternygaard/anaconda3/lib/python3.6/site-packages/selenium/webdriver/chromedriver'
driver = webdriver.Chrome(DRIVER)
driver.get("https://stats.nba.com/players/traditional/?sort=PLAYER_NAME&dir=-1&Season=2014-15&SeasonType=Regular%20Season&PerMode=Totals")
driver.implicitly_wait(2)
soup_level1 = BeautifulSoup(driver.page_source, 'lxml')
page_1 = soup_level1.find_all('a')[-55:-5]
for i in range(len(page_1)):
     tags.append(['2014-15', str(page_1[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level2 = BeautifulSoup(driver.page_source, 'lxml')
page_2 = soup_level2.find_all('a')[-55:-5]
for i in range(len(page_2)):
     tags.append(['2014-15', str(page_2[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level3 = BeautifulSoup(driver.page_source, 'lxml')
page_3 = soup_level3.find_all('a')[-55:-5]
for i in range(len(page_3)):
     tags.append(['2014-15', str(page_3[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level4 = BeautifulSoup(driver.page_source, 'lxml')
page_4 = soup_level4.find_all('a')[-55:-5]
for i in range(len(page_4)):
     tags.append(['2014-15', str(page_4[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level5 = BeautifulSoup(driver.page_source, 'lxml')
page_5 = soup_level5.find_all('a')[-55:-5]
for i in range(len(page_5)):
     tags.append(['2014-15', str(page_5[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level6 = BeautifulSoup(driver.page_source, 'lxml')
page_6 = soup_level6.find_all('a')[-55:-5]
for i in range(len(page_6)):
     tags.append(['2014-15', str(page_6[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level7 = BeautifulSoup(driver.page_source, 'lxml')
page_7 = soup_level7.find_all('a')[-55:-5]
for i in range(len(page_7)):
     tags.append(['2014-15', str(page_7[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level8 = BeautifulSoup(driver.page_source, 'lxml')
page_8 = soup_level8.find_all('a')[-55:-5]
for i in range(len(page_8)):
     tags.append(['2014-15', str(page_8[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level9 = BeautifulSoup(driver.page_source, 'lxml')
page_9 = soup_level9.find_all('a')[-55:-5]
for i in range(len(page_9)):
     tags.append(['2014-15', str(page_9[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level10 = BeautifulSoup(driver.page_source, 'lxml')
page_10 = soup_level10.find_all('a')[-47:-5]
for i in range(len(page_10)):
     tags.append(['2014-15', str(page_10[i]).split('/')[2]])
driver.quit()

DRIVER = '/Users/peternygaard/anaconda3/lib/python3.6/site-packages/selenium/webdriver/chromedriver'
driver = webdriver.Chrome(DRIVER)
driver.get("https://stats.nba.com/players/traditional/?sort=PLAYER_NAME&dir=-1&Season=2015-16&SeasonType=Regular%20Season&PerMode=Totals")
driver.implicitly_wait(2)
soup_level1 = BeautifulSoup(driver.page_source, 'lxml')
page_1 = soup_level1.find_all('a')[-55:-5]
for i in range(len(page_1)):
     tags.append(['2015-16', str(page_1[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level2 = BeautifulSoup(driver.page_source, 'lxml')
page_2 = soup_level2.find_all('a')[-55:-5]
for i in range(len(page_2)):
     tags.append(['2015-16', str(page_2[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level3 = BeautifulSoup(driver.page_source, 'lxml')
page_3 = soup_level3.find_all('a')[-55:-5]
for i in range(len(page_3)):
     tags.append(['2015-16', str(page_3[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level4 = BeautifulSoup(driver.page_source, 'lxml')
page_4 = soup_level4.find_all('a')[-55:-5]
for i in range(len(page_4)):
     tags.append(['2015-16', str(page_4[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level5 = BeautifulSoup(driver.page_source, 'lxml')
page_5 = soup_level5.find_all('a')[-55:-5]
for i in range(len(page_5)):
     tags.append(['2015-16', str(page_5[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level6 = BeautifulSoup(driver.page_source, 'lxml')
page_6 = soup_level6.find_all('a')[-55:-5]
for i in range(len(page_6)):
     tags.append(['2015-16', str(page_6[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level7 = BeautifulSoup(driver.page_source, 'lxml')
page_7 = soup_level7.find_all('a')[-55:-5]
for i in range(len(page_7)):
     tags.append(['2015-16', str(page_7[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level8 = BeautifulSoup(driver.page_source, 'lxml')
page_8 = soup_level8.find_all('a')[-55:-5]
for i in range(len(page_8)):
     tags.append(['2015-16', str(page_8[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level9 = BeautifulSoup(driver.page_source, 'lxml')
page_9 = soup_level9.find_all('a')[-55:-5]
for i in range(len(page_9)):
     tags.append(['2015-16', str(page_9[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level10 = BeautifulSoup(driver.page_source, 'lxml')
page_10 = soup_level10.find_all('a')[-31:-5]
for i in range(len(page_10)):
     tags.append(['2015-16', str(page_10[i]).split('/')[2]])
driver.quit()

DRIVER = '/Users/peternygaard/anaconda3/lib/python3.6/site-packages/selenium/webdriver/chromedriver'
driver = webdriver.Chrome(DRIVER)
driver.get("https://stats.nba.com/players/traditional/?sort=PLAYER_NAME&dir=-1&Season=2016-17&SeasonType=Regular%20Season&PerMode=Totals")
driver.implicitly_wait(2)
soup_level1 = BeautifulSoup(driver.page_source, 'lxml')
page_1 = soup_level1.find_all('a')[-55:-5]
for i in range(len(page_1)):
     tags.append(['2016-17', str(page_1[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level2 = BeautifulSoup(driver.page_source, 'lxml')
page_2 = soup_level2.find_all('a')[-55:-5]
for i in range(len(page_2)):
     tags.append(['2016-17', str(page_2[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level3 = BeautifulSoup(driver.page_source, 'lxml')
page_3 = soup_level3.find_all('a')[-55:-5]
for i in range(len(page_3)):
     tags.append(['2016-17', str(page_3[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level4 = BeautifulSoup(driver.page_source, 'lxml')
page_4 = soup_level4.find_all('a')[-55:-5]
for i in range(len(page_4)):
     tags.append(['2016-17', str(page_4[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level5 = BeautifulSoup(driver.page_source, 'lxml')
page_5 = soup_level5.find_all('a')[-55:-5]
for i in range(len(page_5)):
     tags.append(['2016-17', str(page_5[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level6 = BeautifulSoup(driver.page_source, 'lxml')
page_6 = soup_level6.find_all('a')[-55:-5]
for i in range(len(page_6)):
     tags.append(['2016-17', str(page_6[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level7 = BeautifulSoup(driver.page_source, 'lxml')
page_7 = soup_level7.find_all('a')[-55:-5]
for i in range(len(page_7)):
     tags.append(['2016-17', str(page_7[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level8 = BeautifulSoup(driver.page_source, 'lxml')
page_8 = soup_level8.find_all('a')[-55:-5]
for i in range(len(page_8)):
     tags.append(['2016-17', str(page_8[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level9 = BeautifulSoup(driver.page_source, 'lxml')
page_9 = soup_level9.find_all('a')[-55:-5]
for i in range(len(page_9)):
     tags.append(['2016-17', str(page_9[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level10 = BeautifulSoup(driver.page_source, 'lxml')
page_10 = soup_level10.find_all('a')[-41:-5]
for i in range(len(page_10)):
     tags.append(['2016-17', str(page_10[i]).split('/')[2]])
driver.quit()

DRIVER = '/Users/peternygaard/anaconda3/lib/python3.6/site-packages/selenium/webdriver/chromedriver'
driver = webdriver.Chrome(DRIVER)
driver.get("https://stats.nba.com/players/traditional/?sort=PLAYER_NAME&dir=-1&Season=2017-18&SeasonType=Regular%20Season&PerMode=Totals")
driver.implicitly_wait(2)
soup_level1 = BeautifulSoup(driver.page_source, 'lxml')
page_1 = soup_level1.find_all('a')[-55:-5]
for i in range(len(page_1)):
     tags.append(['2017-18', str(page_1[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level2 = BeautifulSoup(driver.page_source, 'lxml')
page_2 = soup_level2.find_all('a')[-55:-5]
for i in range(len(page_2)):
     tags.append(['2017-18', str(page_2[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level3 = BeautifulSoup(driver.page_source, 'lxml')
page_3 = soup_level3.find_all('a')[-55:-5]
for i in range(len(page_3)):
     tags.append(['2017-18', str(page_3[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level4 = BeautifulSoup(driver.page_source, 'lxml')
page_4 = soup_level4.find_all('a')[-55:-5]
for i in range(len(page_4)):
     tags.append(['2017-18', str(page_4[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level5 = BeautifulSoup(driver.page_source, 'lxml')
page_5 = soup_level5.find_all('a')[-55:-5]
for i in range(len(page_5)):
     tags.append(['2017-18', str(page_5[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level6 = BeautifulSoup(driver.page_source, 'lxml')
page_6 = soup_level6.find_all('a')[-55:-5]
for i in range(len(page_6)):
     tags.append(['2017-18', str(page_6[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level7 = BeautifulSoup(driver.page_source, 'lxml')
page_7 = soup_level7.find_all('a')[-55:-5]
for i in range(len(page_7)):
     tags.append(['2017-18', str(page_7[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level8 = BeautifulSoup(driver.page_source, 'lxml')
page_8 = soup_level8.find_all('a')[-55:-5]
for i in range(len(page_8)):
     tags.append(['2017-18', str(page_8[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level9 = BeautifulSoup(driver.page_source, 'lxml')
page_9 = soup_level9.find_all('a')[-55:-5]
for i in range(len(page_9)):
     tags.append(['2017-18', str(page_9[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level10 = BeautifulSoup(driver.page_source, 'lxml')
page_10 = soup_level10.find_all('a')[-55:-5]
for i in range(len(page_10)):
     tags.append(['2017-18', str(page_10[i]).split('/')[2]])
driver.find_element(By.CLASS_NAME, 'stats-table-pagination__next').click()
soup_level11 = BeautifulSoup(driver.page_source, 'lxml')
page_11 = soup_level11.find_all('a')[-45:-5]
for i in range(len(page_11)):
     tags.append(['2017-18', str(page_11[i]).split('/')[2]])
driver.quit()

# %%
tags
# Out:
# [['1996-97', '920'],
#  ['1996-97', '243'],
#  ['1996-97', '1425'],
#  ['1996-97', '768'],
#  ['1996-97', '228'],
#  ['1996-97', '154'],
#  ['1996-97', '673'],
#  ['1996-97', '1059'],
#  ['1996-97', '275'],
#  ['1996-97', '947'],
#  ['1996-97', '297'],
#  ['1996-97', '175'],
#  ['1996-97', '1043'],
#  ['1996-97', '692'],
#  ['1996-97', '457'],
#  ['1996-97', '358'],
#  ['1996-97', '924'],
#  ['1996-97', '193'],
#  ['1996-97', '292'],
#  ['1996-97', '324'],
#  ['1996-97', '156'],
#  ['1996-97', '952'],
#  ['1996-97', '213'],
#  ['1996-97', '176'],
#  ['1996-97', '226'],
#  ['1996-97', '686'],
#  ['1996-97', '288'],
#  ['1996-97', '717'],
#  ['1996-97', '732'],
#  ['1996-97', '422'],
#  ['1996-97', '769'],
#  ['1996-97', '989'],
#  ['1996-97', '1112'],
#  ['1996-97', '104'],
#  ['1996-97', '82'],
#  ['1996-97', '182'],
#  ['1996-97', '902'],
#  ['1996-97', '183'],
#  ['1996-97', '898'],
#  ['1996-97', '448'],
#  ['1996-97', '682'],
#  ['1996-97', '310'],
#  ['1996-97', '184'],
#  ['1996-97', '38'],
#  ['1996-97', '699'],
#  ['1996-97', '85'],
#  ['1996-97', '1064'],
#  ['1996-97', '1136'],
#  ['1996-97', '967'],
#  ['1996-97', '258'],
#  ['1996-97', '216'],
#  ['1996-97', '240'],
#  ['1996-97', '1477'],
#  ['1996-97', '735'],
#  ['1996-97', '179'],
#  ['1996-97', '935'],
#  ['1996-97', '433'],
#  ['1996-97', '2'],
#  ['1996-97', '384'],
#  ['1996-97', '61'],
#  ['1996-97', '1063'],
#  ['1996-97', '435'],
#  ['1996-97', '76'],
#  ['1996-97', '787'],
#  ['1996-97', '279'],
#  ['1996-97', '891'],
#  ['1996-97', '293'],
#  ['1996-97', '369'],
#  ['1996-97', '685'],
#  ['1996-97', '713'],
#  ['1996-97', '164'],
#  ['1996-97', '201'],
#  ['1996-97', '423'],
#  ['1996-97', '1137'],
#  ['1996-97', '168'],
#  ['1996-97', '356'],
#  ['1996-97', '904'],
#  ['1996-97', '997'],
#  ['1996-97', '185'],
#  ['1996-97', '43'],
#  ['1996-97', '363'],
#  ['1996-97', '359'],
#  ['1996-97', '221'],
#  ['1996-97', '361'],
#  ['1996-97', '32'],
#  ['1996-97', '17'],
#  ['1996-97', '916'],
#  ['1996-97', '722'],
#  ['1996-97', '724'],
#  ['1996-97', '378'],
#  ['1996-97', '733'],
#  ['1996-97', '905'],
#  ['1996-97', '107'],
#  ['1996-97', '757'],
#  ['1996-97', '105'],
#  ['1996-97', '7'],
#  ['1996-97', '344'],
#  ['1996-97', '198'],
#  ['1996-97', '330'],
#  ['1996-97', '353'],
#  ['1996-97', '239'],
#  ['1996-97', '241'],
#  ['1996-97', '1032'],
#  ['1996-97', '764'],
#  ['1996-97', '710'],
#  ['1996-97', '133'],
#  ['1996-97', '766'],
#  ['1996-97', '116'],
#  ['1996-97', '1051'],
#  ['1996-97', '244'],
#  ['1996-97', '209'],
#  ['1996-97', '725'],
#  ['1996-97', '23'],
#  ['1996-97', '192'],
#  ['1996-97', '965'],
#  ['1996-97', '157'],
#  ['1996-97', '400'],
#  ['1996-97', '308'],
#  ['1996-97', '934'],
#  ['1996-97', '365'],
#  ['1996-97', '96'],
#  ['1996-97', '1070'],
#  ['1996-97', '1121'],
#  ['1996-97', '54'],
#  ['1996-97', '87'],
#  ['1996-97', '129'],
#  ['1996-97', '1122'],
#  ['1996-97', '931'],
#  ['1996-97', '690'],
#  ['1996-97', '140'],
#  ['1996-97', '1126'],
#  ['1996-97', '671'],
#  ['1996-97', '681'],
#  ['1996-97', '112'],
#  ['1996-97', '923'],
#  ['1996-97', '57'],
#  ['1996-97', '77'],
#  ['1996-97', '28'],
#  ['1996-97', '190'],
#  ['1996-97', '273'],
#  ['1996-97', '368'],
#  ['1996-97', '940'],
#  ['1996-97', '709'],
#  ['1996-97', '291'],
#  ['1996-97', '698'],
#  ['1996-97', '224'],
#  ['1996-97', '922'],
#  ['1996-97', '695'],
#  ['1996-97', '386'],
#  ['1996-97', '1120'],
#  ['1996-97', '771'],
#  ['1996-97', '1023'],
#  ['1996-97', '941'],
#  ['1996-97', '287'],
#  ['1996-97', '211'],
#  ['1996-97', '376'],
#  ['1996-97', '785'],
#  ['1996-97', '15'],
#  ['1996-97', '727'],
#  ['1996-97', '677'],
#  ['1996-97', '956'],
#  ['1996-97', '1065'],
#  ['1996-97', '911'],
#  ['1996-97', '1026'],
#  ['1996-97', '280'],
#  ['1996-97', '783'],
#  ['1996-97', '701'],
#  ['1996-97', '697'],
#  ['1996-97', '122'],
#  ['1996-97', '202'],
#  ['1996-97', '56'],
#  ['1996-97', '718'],
#  ['1996-97', '1093'],
#  ['1996-97', '248'],
#  ['1996-97', '45'],
#  ['1996-97', '678'],
#  ['1996-97', '786'],
#  ['1996-97', '49'],
#  ['1996-97', '779'],
#  ['1996-97', '299'],
#  ['1996-97', '255'],
#  ['1996-97', '3'],
#  ['1996-97', '246'],
#  ['1996-97', '21'],
#  ['1996-97', '1068'],
#  ['1996-97', '323'],
#  ['1996-97', '37'],
#  ['1996-97', '65'],
#  ['1996-97', '731'],
#  ['1996-97', '165'],
#  ['1996-97', '265'],
#  ['1996-97', '906'],
#  ['1996-97', '1080'],
#  ['1996-97', '1006'],
#  ['1996-97', '765'],
#  ['1996-97', '270'],
#  ['1996-97', '1024'],
#  ['1996-97', '73'],
#  ['1996-97', '458'],
#  ['1996-97', '93'],
#  ['1996-97', '1134'],
#  ['1996-97', '375'],
#  ['1996-97', '1096'],
#  ['1996-97', '917'],
#  ['1996-97', '147'],
#  ['1996-97', '469'],
#  ['1996-97', '381'],
#  ['1996-97', '1109'],
#  ['1996-97', '994'],
#  ['1996-97', '320'],
#  ['1996-97', '1114'],
#  ['1996-97', '679'],
#  ['1996-97', '467'],
#  ['1996-97', '987'],
#  ['1996-97', '420'],
#  ['1996-97', '81'],
#  ['1996-97', '204'],
#  ['1996-97', '976'],
#  ['1996-97', '979'],
#  ['1996-97', '706'],
#  ['1996-97', '760'],
#  ['1996-97', '966'],
#  ['1996-97', '711'],
#  ['1996-97', '754'],
#  ['1996-97', '29'],
#  ['1996-97', '1131'],
#  ['1996-97', '728'],
#  ['1996-97', '1429'],
#  ['1996-97', '1432'],
#  ['1996-97', '247'],
#  ['1996-97', '170'],
#  ['1996-97', '693'],
#  ['1996-97', '1086'],
#  ['1996-97', '341'],
#  ['1996-97', '180'],
#  ['1996-97', '1381'],
#  ['1996-97', '317'],
#  ['1996-97', '304'],
#  ['1996-97', '961'],
#  ['1996-97', '271'],
#  ['1996-97', '468'],
#  ['1996-97', '146'],
#  ['1996-97', '436'],
#  ['1996-97', '252'],
#  ['1996-97', '173'],
#  ['1996-97', '700'],
#  ['1996-97', '80'],
#  ['1996-97', '383'],
#  ['1996-97', '72'],
#  ['1996-97', '181'],
#  ['1996-97', '954'],
#  ['1996-97', '404'],
#  ['1996-97', '236'],
#  ['1996-97', '333'],
#  ['1996-97', '708'],
#  ['1996-97', '134'],
#  ['1996-97', '1089'],
#  ['1996-97', '788'],
#  ['1996-97', '234'],
#  ['1996-97', '977'],
#  ['1996-97', '703'],
#  ['1996-97', '111'],
#  ['1996-97', '78'],
#  ['1996-97', '441'],
#  ['1996-97', '913'],
#  ['1996-97', '1474'],
#  ['1996-97', '1125'],
#  ['1996-97', '84'],
#  ['1996-97', '734'],
#  ['1996-97', '195'],
#  ['1996-97', '283'],
#  ['1996-97', '1489'],
#  ['1996-97', '1036'],
#  ['1996-97', '1380'],
#  ['1996-97', '684'],
#  ['1996-97', '953'],
#  ['1996-97', '31'],
#  ['1996-97', '691'],
#  ['1996-97', '919'],
#  ['1996-97', '26'],
#  ['1996-97', '446'],
#  ['1996-97', '51'],
#  ['1996-97', '990'],
#  ['1996-97', '907'],
#  ['1996-97', '992'],
#  ['1996-97', '948'],
#  ['1996-97', '53'],
#  ['1996-97', '1361'],
#  ['1996-97', '95'],
#  ['1996-97', '707'],
#  ['1996-97', '971'],
#  ['1996-97', '349'],
#  ['1996-97', '899'],
#  ['1996-97', '1110'],
#  ['1996-97', '770'],
#  ['1996-97', '729'],
#  ['1996-97', '982'],
#  ['1996-97', '55'],
#  ['1996-97', '672'],
#  ['1996-97', '900'],
#  ['1996-97', '761'],
#  ['1996-97', '1074'],
#  ['1996-97', '1099'],
#  ['1996-97', '511'],
#  ['1996-97', '262'],
#  ['1996-97', '688'],
#  ['1996-97', '714'],
#  ['1996-97', '1138'],
#  ['1996-97', '893'],
#  ['1996-97', '63'],
#  ['1996-97', '1479'],
#  ['1996-97', '782'],
#  ['1996-97', '348'],
#  ['1996-97', '42'],
#  ['1996-97', '983'],
#  ['1996-97', '302'],
#  ['1996-97', '177'],
#  ['1996-97', '1041'],
#  ['1996-97', '203'],
#  ['1996-97', '98'],
#  ['1996-97', '89'],
#  ['1996-97', '178'],
#  ['1996-97', '932'],
#  ['1996-97', '970'],
#  ['1996-97', '901'],
#  ['1996-97', '136'],
#  ['1996-97', '121'],
#  ['1996-97', '442'],
#  ['1996-97', '432'],
#  ['1996-97', '71'],
#  ['1996-97', '461'],
#  ['1996-97', '968'],
#  ['1996-97', '912'],
#  ['1996-97', '719'],
#  ['1996-97', '753'],
#  ['1996-97', '988'],
#  ['1996-97', '739'],
#  ['1996-97', '951'],
#  ['1996-97', '1077'],
#  ['1996-97', '1002'],
#  ['1996-97', '674'],
#  ['1996-97', '397'],
#  ['1996-97', '1073'],
#  ['1996-97', '199'],
#  ['1996-97', '364'],
#  ['1996-97', '777'],
#  ['1996-97', '316'],
#  ['1996-97', '296'],
#  ['1996-97', '328'],
#  ['1996-97', '894'],
#  ['1996-97', '22'],
#  ['1996-97', '109'],
#  ['1996-97', '123'],
#  ['1996-97', '305'],
#  ['1996-97', '438'],
#  ['1996-97', '393'],
#  ['1996-97', '915'],
#  ['1996-97', '166'],
#  ['1996-97', '938'],
#  ['1996-97', '964'],
#  ['1996-97', '1129'],
#  ['1996-97', '716'],
#  ['1996-97', '208'],
#  ['1996-97', '694'],
#  ['1996-97', '417'],
#  ['1996-97', '64'],
#  ['1996-97', '955'],
#  ['1996-97', '36'],
#  ['1996-97', '390'],
#  ['1996-97', '418'],
#  ['1996-97', '197'],
#  ['1996-97', '281'],
#  ['1996-97', '937'],
#  ['1996-97', '251'],
#  ['1996-97', '399'],
#  ['1996-97', '9'],
#  ['1996-97', '1000'],
#  ['1996-97', '1049'],
#  ['1996-97', '406'],
#  ['1996-97', '949'],
#  ['1996-97', '412'],
#  ['1996-97', '762'],
#  ['1996-97', '431'],
#  ['1996-97', '704'],
#  ['1996-97', '1035'],
#  ['1996-97', '428'],
#  ['1996-97', '278'],
#  ['1996-97', '351'],
#  ['1996-97', '914'],
#  ['1996-97', '1128'],
#  ['1996-97', '950'],
#  ['1996-97', '984'],
#  ['1996-97', '70'],
#  ['1996-97', '959'],
#  ['1996-97', '88'],
#  ['1996-97', '120'],
#  ['1996-97', '1478'],
#  ['1996-97', '1037'],
#  ['1996-97', '210'],
#  ['1996-97', '187'],
#  ['1996-97', '100'],
#  ['1996-97', '103'],
#  ['1996-97', '957'],
#  ['1996-97', '1472'],
#  ['1996-97', '339'],
#  ['1996-97', '67'],
#  ['1996-97', '389'],
#  ['1996-97', '960'],
#  ['1996-97', '434'],
#  ['1996-97', '763'],
#  ['1996-97', '380'],
#  ['1996-97', '929'],
#  ['1996-97', '145'],
#  ['1996-97', '696'],
#  ['1996-97', '969'],
#  ['1996-97', '895'],
#  ['1996-97', '238'],
#  ['1996-97', '721'],
#  ['1996-97', '137'],
#  ['1996-97', '452'],
#  ['1996-97', '355'],
#  ['1996-97', '219'],
#  ['1996-97', '958'],
#  ['1996-97', '124'],
#  ['1996-97', '702'],
#  ['1996-97', '1005'],
#  ['1996-97', '962'],
#  ['1996-97', '47'],
#  ['1996-97', '445'],
#  ['1996-97', '781'],
#  ['1996-97', '335'],
#  ['1996-97', '416'],
#  ['1996-97', '1365'],
#  ['1996-97', '212'],
#  ['1996-97', '440'],
#  ['1996-97', '775'],
#  ['1996-97', '1489'],
#  ['1996-97', '93'],
#  ['1996-97', '902'],
#  ['1996-97', '1049'],
#  ['1996-97', '2179'],
#  ['1997-98', '920'],
#  ['1997-98', '243'],
#  ['1997-98', '1425'],
#  ['1997-98', '228'],
#  ['1997-98', '1502'],
#  ['1997-98', '154'],
#  ['1997-98', '673'],
#  ['1997-98', '275'],
#  ['1997-98', '947'],
#  ['1997-98', '297'],
#  ['1997-98', '175'],
#  ['1997-98', '1541'],
#  ['1997-98', '692'],
#  ['1997-98', '457'],
#  ['1997-98', '358'],
#  ['1997-98', '194'],
#  ['1997-98', '924'],
#  ['1997-98', '1533'],
#  ['1997-98', '193'],
#  ['1997-98', '292'],
#  ['1997-98', '1515'],
#  ['1997-98', '324'],
#  ['1997-98', '156'],
#  ['1997-98', '952'],
#  ['1997-98', '1498'],
#  ['1997-98', '213'],
#  ['1997-98', '226'],
#  ['1997-98', '686'],
#  ['1997-98', '288'],
#  ['1997-98', '717'],
#  ['1997-98', '1506'],
#  ['1997-98', '422'],
#  ['1997-98', '769'],
#  ['1997-98', '989'],
#  ['1997-98', '1112'],
#  ['1997-98', '104'],
#  ['1997-98', '223'],
#  ['1997-98', '82'],
#  ['1997-98', '182'],
#  ['1997-98', '902'],
#  ['1997-98', '183'],
#  ['1997-98', '898'],
#  ['1997-98', '448'],
#  ['1997-98', '737'],
#  ['1997-98', '682'],
#  ['1997-98', '310'],
#  ['1997-98', '1517'],
#  ['1997-98', '184'],
#  ['1997-98', '38'],
#  ['1997-98', '1585'],
#  ['1997-98', '699'],
#  ['1997-98', '85'],
#  ['1997-98', '1510'],
#  ['1997-98', '967'],
#  ['1997-98', '258'],
#  ['1997-98', '1680'],
#  ['1997-98', '216'],
#  ['1997-98', '240'],
#  ['1997-98', '1477'],
#  ['1997-98', '735'],
#  ['1997-98', '179'],
#  ['1997-98', '935'],
#  ['1997-98', '1528'],
#  ['1997-98', '433'],
#  ['1997-98', '384'],
#  ['1997-98', '61'],
#  ['1997-98', '1063'],
#  ['1997-98', '435'],
#  ['1997-98', '76'],
#  ['1997-98', '1538'],
#  ['1997-98', '787'],
#  ['1997-98', '279'],
#  ['1997-98', '1525'],
#  ['1997-98', '891'],
#  ['1997-98', '1520'],
#  ['1997-98', '369'],
#  ['1997-98', '1497'],
#  ['1997-98', '685'],
#  ['1997-98', '1512'],
#  ['1997-98', '713'],
#  ['1997-98', '164'],
#  ['1997-98', '1544'],
#  ['1997-98', '201'],
#  ['1997-98', '1612'],
#  ['1997-98', '423'],
#  ['1997-98', '168'],
#  ['1997-98', '356'],
#  ['1997-98', '904'],
#  ['1997-98', '997'],
#  ['1997-98', '185'],
#  ['1997-98', '43'],
#  ['1997-98', '363'],
#  ['1997-98', '456'],
#  ['1997-98', '359'],
#  ['1997-98', '221'],
#  ['1997-98', '361'],
#  ['1997-98', '32'],
#  ['1997-98', '17'],
#  ['1997-98', '1133'],
#  ['1997-98', '916'],
#  ['1997-98', '722'],
#  ['1997-98', '724'],
#  ['1997-98', '905'],
#  ['1997-98', '107'],
#  ['1997-98', '757'],
#  ['1997-98', '105'],
#  ['1997-98', '7'],
#  ['1997-98', '344'],
#  ['1997-98', '198'],
#  ['1997-98', '1504'],
#  ['1997-98', '330'],
#  ['1997-98', '353'],
#  ['1997-98', '239'],
#  ['1997-98', '1032'],
#  ['1997-98', '128'],
#  ['1997-98', '764'],
#  ['1997-98', '710'],
#  ['1997-98', '133'],
#  ['1997-98', '766'],
#  ['1997-98', '1545'],
#  ['1997-98', '1051'],
#  ['1997-98', '244'],
#  ['1997-98', '209'],
#  ['1997-98', '23'],
#  ['1997-98', '192'],
#  ['1997-98', '1507'],
#  ['1997-98', '965'],
#  ['1997-98', '1575'],
#  ['1997-98', '157'],
#  ['1997-98', '400'],
#  ['1997-98', '934'],
#  ['1997-98', '365'],
#  ['1997-98', '96'],
#  ['1997-98', '54'],
#  ['1997-98', '87'],
#  ['1997-98', '931'],
#  ['1997-98', '690'],
#  ['1997-98', '140'],
#  ['1997-98', '1126'],
#  ['1997-98', '963'],
#  ['1997-98', '112'],
#  ['1997-98', '923'],
#  ['1997-98', '57'],
#  ['1997-98', '77'],
#  ['1997-98', '28'],
#  ['1997-98', '1003'],
#  ['1997-98', '190'],
#  ['1997-98', '273'],
#  ['1997-98', '1516'],
#  ['1997-98', '1055'],
#  ['1997-98', '698'],
#  ['1997-98', '224'],
#  ['1997-98', '922'],
#  ['1997-98', '695'],
#  ['1997-98', '386'],
#  ['1997-98', '1023'],
#  ['1997-98', '376'],
#  ['1997-98', '785'],
#  ['1997-98', '15'],
#  ['1997-98', '35'],
#  ['1997-98', '727'],
#  ['1997-98', '1540'],
#  ['1997-98', '677'],
#  ['1997-98', '956'],
#  ['1997-98', '1065'],
#  ['1997-98', '911'],
#  ['1997-98', '1564'],
#  ['1997-98', '280'],
#  ['1997-98', '697'],
#  ['1997-98', '202'],
#  ['1997-98', '56'],
#  ['1997-98', '718'],
#  ['1997-98', '248'],
#  ['1997-98', '45'],
#  ['1997-98', '678'],
#  ['1997-98', '1666'],
#  ['1997-98', '786'],
#  ['1997-98', '779'],
#  ['1997-98', '299'],
#  ['1997-98', '1539'],
#  ['1997-98', '255'],
#  ['1997-98', '3'],
#  ['1997-98', '246'],
#  ['1997-98', '21'],
#  ['1997-98', '323'],
#  ['1997-98', '37'],
#  ['1997-98', '65'],
#  ['1997-98', '731'],
#  ['1997-98', '165'],
#  ['1997-98', '1677'],
#  ['1997-98', '265'],
#  ['1997-98', '1080'],
#  ['1997-98', '1006'],
#  ['1997-98', '765'],
#  ['1997-98', '270'],
#  ['1997-98', '1024'],
#  ['1997-98', '73'],
#  ['1997-98', '458'],
#  ['1997-98', '93'],
#  ['1997-98', '1134'],
#  ['1997-98', '375'],
#  ['1997-98', '1096'],
#  ['1997-98', '462'],
#  ['1997-98', '917'],
#  ['1997-98', '1521'],
#  ['1997-98', '147'],
#  ['1997-98', '469'],
#  ['1997-98', '1530'],
#  ['1997-98', '1526'],
#  ['1997-98', '381'],
#  ['1997-98', '994'],
#  ['1997-98', '1114'],
#  ['1997-98', '679'],
#  ['1997-98', '467'],
#  ['1997-98', '1535'],
#  ['1997-98', '420'],
#  ['1997-98', '81'],
#  ['1997-98', '204'],
#  ['1997-98', '999'],
#  ['1997-98', '1532'],
#  ['1997-98', '979'],
#  ['1997-98', '760'],
#  ['1997-98', '966'],
#  ['1997-98', '711'],
#  ['1997-98', '754'],
#  ['1997-98', '29'],
#  ['1997-98', '1429'],
#  ['1997-98', '247'],
#  ['1997-98', '170'],
#  ['1997-98', '693'],
#  ['1997-98', '1086'],
#  ['1997-98', '341'],
#  ['1997-98', '180'],
#  ['1997-98', '317'],
#  ['1997-98', '304'],
#  ['1997-98', '1519'],
#  ['1997-98', '961'],
#  ['1997-98', '271'],
#  ['1997-98', '1511'],
#  ['1997-98', '468'],
#  ['1997-98', '146'],
#  ['1997-98', '436'],
#  ['1997-98', '252'],
#  ['1997-98', '1529'],
#  ['1997-98', '173'],
#  ['1997-98', '1522'],
#  ['1997-98', '1569'],
#  ['1997-98', '1496'],
#  ['1997-98', '1509'],
#  ['1997-98', '383'],
#  ['1997-98', '72'],
#  ['1997-98', '954'],
#  ['1997-98', '236'],
#  ['1997-98', '708'],
#  ['1997-98', '134'],
#  ['1997-98', '1563'],
#  ['1997-98', '1089'],
#  ['1997-98', '788'],
#  ['1997-98', '234'],
#  ['1997-98', '1619'],
#  ['1997-98', '977'],
#  ['1997-98', '703'],
#  ['1997-98', '111'],
#  ['1997-98', '441'],
#  ['1997-98', '913'],
#  ['1997-98', '1683'],
#  ['1997-98', '84'],
#  ['1997-98', '1444'],
#  ['1997-98', '734'],
#  ['1997-98', '289'],
#  ['1997-98', '195'],
#  ['1997-98', '283'],
#  ['1997-98', '1036'],
#  ['1997-98', '1380'],
#  ['1997-98', '953'],
#  ['1997-98', '31'],
#  ['1997-98', '919'],
#  ['1997-98', '26'],
#  ['1997-98', '446'],
#  ['1997-98', '51'],
#  ['1997-98', '990'],
#  ['1997-98', '907'],
#  ['1997-98', '948'],
#  ['1997-98', '712'],
#  ['1997-98', '53'],
#  ['1997-98', '95'],
#  ['1997-98', '707'],
#  ['1997-98', '971'],
#  ['1997-98', '349'],
#  ['1997-98', '998'],
#  ['1997-98', '899'],
#  ['1997-98', '1110'],
#  ['1997-98', '770'],
#  ['1997-98', '1527'],
#  ['1997-98', '982'],
#  ['1997-98', '55'],
#  ['1997-98', '672'],
#  ['1997-98', '761'],
#  ['1997-98', '1074'],
#  ['1997-98', '1508'],
#  ['1997-98', '262'],
#  ['1997-98', '688'],
#  ['1997-98', '714'],
#  ['1997-98', '893'],
#  ['1997-98', '1075'],
#  ['1997-98', '63'],
#  ['1997-98', '1565'],
#  ['1997-98', '52'],
#  ['1997-98', '782'],
#  ['1997-98', '348'],
#  ['1997-98', '42'],
#  ['1997-98', '302'],
#  ['1997-98', '177'],
#  ['1997-98', '203'],
#  ['1997-98', '98'],
#  ['1997-98', '89'],
#  ['1997-98', '178'],
#  ['1997-98', '932'],
#  ['1997-98', '970'],
#  ['1997-98', '901'],
#  ['1997-98', '136'],
#  ['1997-98', '121'],
#  ['1997-98', '442'],
#  ['1997-98', '432'],
#  ['1997-98', '939'],
#  ['1997-98', '71'],
#  ['1997-98', '461'],
#  ['1997-98', '968'],
#  ['1997-98', '753'],
#  ['1997-98', '988'],
#  ['1997-98', '739'],
#  ['1997-98', '951'],
#  ['1997-98', '1002'],
#  ['1997-98', '1682'],
#  ['1997-98', '674'],
#  ['1997-98', '397'],
#  ['1997-98', '1073'],
#  ['1997-98', '364'],
#  ['1997-98', '777'],
#  ['1997-98', '1594'],
#  ['1997-98', '296'],
#  ['1997-98', '328'],
#  ['1997-98', '894'],
#  ['1997-98', '22'],
#  ['1997-98', '109'],
#  ['1997-98', '123'],
#  ['1997-98', '393'],
#  ['1997-98', '915'],
#  ['1997-98', '1518'],
#  ['1997-98', '166'],
#  ['1997-98', '1500'],
#  ['1997-98', '938'],
#  ['1997-98', '964'],
#  ['1997-98', '1601'],
#  ['1997-98', '208'],
#  ['1997-98', '694'],
#  ['1997-98', '417'],
#  ['1997-98', '64'],
#  ['1997-98', '955'],
#  ['1997-98', '1513'],
#  ['1997-98', '418'],
#  ['1997-98', '197'],
#  ['1997-98', '281'],
#  ['1997-98', '937'],
#  ['1997-98', '251'],
#  ['1997-98', '925'],
#  ['1997-98', '399'],
#  ['1997-98', '1000'],
#  ['1997-98', '406'],
#  ['1997-98', '949'],
#  ['1997-98', '412'],
#  ['1997-98', '762'],
#  ['1997-98', '431'],
#  ['1997-98', '704'],
#  ['1997-98', '1035'],
#  ['1997-98', '1578'],
#  ['1997-98', '428'],
#  ['1997-98', '892'],
#  ['1997-98', '278'],
#  ['1997-98', '914'],
#  ['1997-98', '1128'],
#  ['1997-98', '950'],
#  ['1997-98', '1667'],
#  ['1997-98', '70'],
#  ['1997-98', '959'],
#  ['1997-98', '120'],
#  ['1997-98', '1037'],
#  ['1997-98', '1505'],
#  ['1997-98', '210'],
#  ['1997-98', '187'],
#  ['1997-98', '426'],
#  ['1997-98', '143'],
#  ['1997-98', '371'],
#  ['1997-98', '345'],
#  ['1997-98', '689'],
#  ['1997-98', '160'],
#  ['1997-98', '1495'],
#  ['1997-98', '896'],
#  ['1997-98', '1118'],
#  ['1997-98', '100'],
#  ['1997-98', '1472'],
#  ['1997-98', '339'],
#  ['1997-98', '67'],
#  ['1997-98', '389'],
#  ['1997-98', '1499'],
#  ['1997-98', '960'],
#  ['1997-98', '434'],
#  ['1997-98', '1108'],
#  ['1997-98', '763'],
#  ['1997-98', '380'],
#  ['1997-98', '1503'],
#  ['1997-98', '145'],
#  ['1997-98', '696'],
#  ['1997-98', '969'],
#  ['1997-98', '1576'],
#  ['1997-98', '1607'],
#  ['1997-98', '895'],
#  ['1997-98', '238'],
#  ['1997-98', '721'],
#  ['1997-98', '137'],
#  ['1997-98', '452'],
#  ['1997-98', '355'],
#  ['1997-98', '219'],
#  ['1997-98', '958'],
#  ['1997-98', '124'],
#  ['1997-98', '702'],
#  ['1997-98', '1005'],
#  ['1997-98', '962'],
#  ['1997-98', '445'],
#  ['1997-98', '781'],
#  ['1997-98', '1061'],
#  ['1997-98', '416'],
#  ['1997-98', '1365'],
#  ['1997-98', '212'],
#  ['1997-98', '440'],
#  ['1997-98', '980'],
#  ['1997-98', '1024'],
#  ['1997-98', '1667'],
#  ['1997-98', '1569'],
#  ['1998-99', '920'],
#  ['1998-99', '243'],
#  ['1998-99', '1425'],
#  ['1998-99', '228'],
#  ['1998-99', '1502'],
#  ['1998-99', '1817'],
#  ['1998-99', '1733'],
#  ['1998-99', '673'],
#  ['1998-99', '275'],
#  ['1998-99', '947'],
#  ['1998-99', '297'],
#  ['1998-99', '1591'],
#  ['1998-99', '1541'],
#  ['1998-99', '1754'],
#  ['1998-99', '692'],
#  ['1998-99', '1845'],
#  ['1998-99', '457'],
#  ['1998-99', '358'],
#  ['1998-99', '1712'],
#  ['1998-99', '138'],
#  ['1998-99', '1533'],
#  ['1998-99', '292'],
#  ['1998-99', '1515'],
#  ['1998-99', '324'],
#  ['1998-99', '156'],
#  ['1998-99', '952'],
#  ['1998-99', '1498'],
#  ['1998-99', '213'],
#  ['1998-99', '226'],
#  ['1998-99', '686'],
#  ['1998-99', '288'],
#  ['1998-99', '717'],
#  ['1998-99', '1506'],
#  ['1998-99', '422'],
#  ['1998-99', '769'],
#  ['1998-99', '989'],
#  ['1998-99', '1112'],
#  ['1998-99', '104'],
#  ['1998-99', '223'],
#  ['1998-99', '82'],
#  ['1998-99', '182'],
#  ['1998-99', '902'],
#  ['1998-99', '183'],
#  ['1998-99', '898'],
#  ['1998-99', '448'],
#  ['1998-99', '682'],
#  ['1998-99', '1517'],
#  ['1998-99', '184'],
#  ['1998-99', '1719'],
#  ['1998-99', '1802'],
#  ['1998-99', '1585'],
#  ['1998-99', '699'],
#  ['1998-99', '85'],
#  ['1998-99', '1510'],
#  ['1998-99', '967'],
#  ['1998-99', '258'],
#  ['1998-99', '216'],
#  ['1998-99', '1730'],
#  ['1998-99', '1477'],
#  ['1998-99', '1743'],
#  ['1998-99', '735'],
#  ['1998-99', '179'],
#  ['1998-99', '1724'],
#  ['1998-99', '935'],
#  ['1998-99', '384'],
#  ['1998-99', '61'],
#  ['1998-99', '435'],
#  ['1998-99', '1745'],
#  ['1998-99', '76'],
#  ['1998-99', '1538'],
#  ['1998-99', '787'],
#  ['1998-99', '1525'],
#  ['1998-99', '891'],
#  ['1998-99', '1869'],
#  ['1998-99', '1593'],
#  ['1998-99', '1520'],
#  ['1998-99', '369'],
#  ['1998-99', '1497'],
#  ['1998-99', '685'],
#  ['1998-99', '1512'],
#  ['1998-99', '713'],
#  ['1998-99', '164'],
#  ['1998-99', '1544'],
#  ['1998-99', '201'],
#  ['1998-99', '423'],
#  ['1998-99', '12'],
#  ['1998-99', '168'],
#  ['1998-99', '356'],
#  ['1998-99', '904'],
#  ['1998-99', '185'],
#  ['1998-99', '43'],
#  ['1998-99', '363'],
#  ['1998-99', '456'],
#  ['1998-99', '359'],
#  ['1998-99', '221'],
#  ['1998-99', '361'],
#  ['1998-99', '1133'],
#  ['1998-99', '1736'],
#  ['1998-99', '916'],
#  ['1998-99', '722'],
#  ['1998-99', '724'],
#  ['1998-99', '1757'],
#  ['1998-99', '1749'],
#  ['1998-99', '905'],
#  ['1998-99', '107'],
#  ['1998-99', '1800'],
#  ['1998-99', '757'],
#  ['1998-99', '105'],
#  ['1998-99', '7'],
#  ['1998-99', '344'],
#  ['1998-99', '198'],
#  ['1998-99', '1504'],
#  ['1998-99', '330'],
#  ['1998-99', '353'],
#  ['1998-99', '239'],
#  ['1998-99', '764'],
#  ['1998-99', '710'],
#  ['1998-99', '133'],
#  ['1998-99', '766'],
#  ['1998-99', '1545'],
#  ...]

# %%
tags[563]
# Out:
# ['1997-98', '209']

# %%
for i in range(7105, 10102):
    url = 'https://stats.nba.com/stats/shotchartdetail?AheadBehind=&CFID=33&CFPARAMS={0}&ClutchTime=&Conference=&ContextFilter=&ContextMeasure=FGA&DateFrom=&DateTo=&Division=&EndPeriod=10&EndRange=28800&GROUP_ID=&GameEventID=&GameID=&GameSegment=&GroupID=&GroupMode=&GroupQuantity=5&LastNGames=0&LeagueID=00&Location=&Month=0&OnOff=&OpponentTeamID=0&Outcome=&PORound=0&Period=0&PlayerID={1}&PlayerID1=&PlayerID2=&PlayerID3=&PlayerID4=&PlayerID5=&PlayerPosition=&PointDiff=&Position=&RangeType=0&RookieYear=&Season={0}&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StartPeriod=1&StartRange=0&StarterBench=&TeamID=0&VsConference=&VsDivision=&VsPlayerID1=&VsPlayerID2=&VsPlayerID3=&VsPlayerID4=&VsPlayerID5=&VsTeamID='.format(tags[i][0], tags[i][1])
    req = requests.get(url, headers={'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
    'Accept-Encoding':'gzip, deflate, br',
    'Accept-Language':'en-US,en;q=0.5',
    'Connection':'keep-alive',
    'Host':'stats.nba.com',
    'Referer':'https://t.co/JllioiHFaO',
    'Upgrade-Insecure-Requests':'1',
    'User-Agent':'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.14; rv:65.0) Gecko/20100101 Firefox/65.0'}).json()
    for j in range(len(req['resultSets'][0]['rowSet'])):
        shots.append([tags[i][0], tags[i][1], req['resultSets'][0]['rowSet'][j][17], req['resultSets'][0]['rowSet'][j][18]])
    print(i, len(tags))
# Out:
# 7105 10101
# 7106 10101
# 7107 10101
# 7108 10101
# 7109 10101
# 7110 10101
# 7111 10101
# 7112 10101
# 7113 10101
# 7114 10101
# 7115 10101
# 7116 10101
# 10016 10101
# 10017 10101
# 10018 10101
# 10019 10101
# 10020 10101
# 10021 10101
# 10022 10101
# 10023 10101
# 10024 10101
# 10025 10101
# 10026 10101
# 10027 10101
# 10028 10101
# 10029 10101
# 10030 10101
# 10031 10101
# 10032 10101
# 10033 10101
# 10034 10101
# 10035 10101
# 10036 10101
# 10037 10101
# 10038 10101
# 10039 10101
# 10040 10101
# 10041 10101
# 10042 10101
# 10043 10101
# 10044 10101
# 10045 10101
# 10046 10101
# 10047 10101
# 10048 10101
# 10049 10101
# 10050 10101
# 10051 10101
# 10052 10101
# 10053 10101
# 10054 10101
# 10055 10101
# 10056 10101
# 10057 10101
# 10058 10101
# 10059 10101
# 10060 10101
# 10061 10101
# 10062 10101
# 10063 10101
# 10064 10101
# 10065 10101
# 10066 10101
# 10067 10101
# 10068 10101
# 10069 10101
# 10070 10101
# 10071 10101
# 10072 10101
# 10073 10101
# 10074 10101
# 10075 10101
# 10076 10101
# 10077 10101
# 10078 10101
# 10079 10101
# 10080 10101
# 10081 10101
# 10082 10101
# 10083 10101
# 10084 10101
# 10085 10101
# 10086 10101
# 10087 10101
# 10088 10101
# 10089 10101
# 10090 10101
# 10091 10101
# 10092 10101
# 10093 10101
# 10094 10101
# 10095 10101
# 10096 10101
# 10097 10101
# 10098 10101
# 10099 10101
# 10100 10101
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-86-3ae95fae7766> in <module>()
#       1 for i in range(7105, 10102):
# ----> 2     url = 'https://stats.nba.com/stats/shotchartdetail?AheadBehind=&CFID=33&CFPARAMS={0}&ClutchTime=&Conference=&ContextFilter=&ContextMeasure=FGA&DateFrom=&DateTo=&Division=&EndPeriod=10&EndRange=28800&GROUP_ID=&GameEventID=&GameID=&GameSegment=&GroupID=&GroupMode=&GroupQuantity=5&LastNGames=0&LeagueID=00&Location=&Month=0&OnOff=&OpponentTeamID=0&Outcome=&PORound=0&Period=0&PlayerID={1}&PlayerID1=&PlayerID2=&PlayerID3=&PlayerID4=&PlayerID5=&PlayerPosition=&PointDiff=&Position=&RangeType=0&RookieYear=&Season={0}&SeasonSegment=&SeasonType=Regular+Season&ShotClockRange=&StartPeriod=1&StartRange=0&StarterBench=&TeamID=0&VsConference=&VsDivision=&VsPlayerID1=&VsPlayerID2=&VsPlayerID3=&VsPlayerID4=&VsPlayerID5=&VsTeamID='.format(tags[i][0], tags[i][1])
#       3     req = requests.get(url, headers={'Accept':'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,*/*;q=0.8',
#       4     'Accept-Encoding':'gzip, deflate, br',
#       5     'Accept-Language':'en-US,en;q=0.5',
#
# IndexError: list index out of range

# %%
df = pd.DataFrame(np.array(shots), columns = ['Year', 'Player_ID', 'X_loc', 'Y_loc'])

# %%
# %matplotlib inline
import requests
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np
import time
import re
import json
from scipy.stats import kde
from matplotlib.patches import Circle, Rectangle, Arc

def draw_court(ax=None, color='black', lw=2, outer_lines=False):
    # If an axes object isn't provided to plot onto, just get current one
    if ax is None:
        ax = plt.gca()

    # Create the various parts of an NBA basketball court

    # Create the basketball hoop
    # Diameter of a hoop is 18" so it has a radius of 9", which is a value
    # 7.5 in our coordinate system
    hoop = Circle((0, 0), radius=7.5, linewidth=lw, color=color, fill=False)

    # Create backboard
    backboard = Rectangle((-30, -7.5), 60, -1, linewidth=lw, color=color)

    # The paint
    # Create the outer box 0f the paint, width=16ft, height=19ft
    outer_box = Rectangle((-80, -47.5), 160, 190, linewidth=lw, color=color,
                          fill=False)
    # Create the inner box of the paint, widt=12ft, height=19ft
    inner_box = Rectangle((-60, -47.5), 120, 190, linewidth=lw, color=color,
                          fill=False)

    # Create free throw top arc
    top_free_throw = Arc((0, 142.5), 120, 120, theta1=0, theta2=180,
                         linewidth=lw, color=color, fill=False)
    # Create free throw bottom arc
    bottom_free_throw = Arc((0, 142.5), 120, 120, theta1=180, theta2=0,
                            linewidth=lw, color=color, linestyle='dashed')
    # Restricted Zone, it is an arc with 4ft radius from center of the hoop
    restricted = Arc((0, 0), 80, 80, theta1=0, theta2=180, linewidth=lw,
                     color=color)

    # Three point line
    # Create the side 3pt lines, they are 14ft long before they begin to arc
    corner_three_a = Rectangle((-220, -47.5), 0, 140, linewidth=lw,
                               color=color)
    corner_three_b = Rectangle((220, -47.5), 0, 140, linewidth=lw, color=color)
    # 3pt arc - center of arc will be the hoop, arc is 23'9" away from hoop
    # I just played around with the theta values until they lined up with the
    # threes
    three_arc = Arc((0, 0), 475, 475, theta1=22, theta2=158, linewidth=lw,
                    color=color)

    # Center Court
    center_outer_arc = Arc((0, 422.5), 120, 120, theta1=180, theta2=0,
                           linewidth=lw, color=color)
    center_inner_arc = Arc((0, 422.5), 40, 40, theta1=180, theta2=0,
                           linewidth=lw, color=color)

    # List of the court elements to be plotted onto the axes
    court_elements = [hoop, backboard, outer_box, inner_box, top_free_throw,
                      bottom_free_throw, restricted, corner_three_a,
                      corner_three_b, three_arc, center_outer_arc,
                      center_inner_arc]

    if outer_lines:
        # Draw the half court line, baseline and side out bound lines
        outer_lines = Rectangle((-250, -47.5), 500, 470, linewidth=lw,
                                color=color, fill=False)
        court_elements.append(outer_lines)

    # Add the court elements onto the axes
    for element in court_elements:
        ax.add_patch(element)

    return ax

all_shots = pd.read_csv('all_shots.csv')

for i in range(830,834):
    df = all_shots[all_shots['Year'] == years[i]]
    df.reset_index(inplace=True, drop=True)
    shots_X = np.array(df[df['Player_ID'] == players[i]]['X_loc'].values)
    shots_y = np.array(df[df['Player_ID'] == players[i]]['Y_loc'].values)

    plt.figure(figsize=(12,11))
    draw_court(outer_lines=True)
    plt.xlim(-251,250)
    plt.ylim(423.5, -47.5)

    # create data
    x = np.array(shots_X)
    y = np.array(shots_y)

    # Evaluate a gaussian kde on a regular grid of nbins x nbins over data extents
    nbins=1000
    k = kde.gaussian_kde([x,y])
    xi, yi = np.mgrid[-251:250:nbins*1j, -47.5:423.5:nbins*1j]
    zi = k(np.vstack([xi.flatten(), yi.flatten()]))

    # Change color palette
    plt.pcolormesh(xi, yi, zi.reshape(xi.shape), cmap=plt.cm.pink)
    plt.savefig('{0}_{1}.png'.format(players[i], years[i]))
    plt.close()
    print(i, len(players))
# Out:
# 830 833
# 831 833
# 832 833
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-70-2cc48dc147c6> in <module>()
#      82
#      83 for i in range(830,834):
# ---> 84     df = all_shots[all_shots['Year'] == years[i]]
#      85     df.reset_index(inplace=True, drop=True)
#      86     shots_X = np.array(df[df['Player_ID'] == players[i]]['X_loc'].values)
#
# IndexError: index 833 is out of bounds for axis 0 with size 833

# %%
all_shots = pd.read_csv('all_shots.csv')

# %%
df2 = all_shots[all_shots['Year'] == all_shots['Year'].unique()[0]]

# %%
all_shots.reset_index(inplace=True, drop=True)

# %%
df['Player_ID'].unique()[448:]
# Out:
# array([1626155,  203816,  203930, 1628400,  201586,  203498,  203894,
#         203499, 1627885,    2733,  202714, 1628414, 1627746,  203524,
#         203915, 1626169,  201939, 1628425,  203500,  204456,  203933,
#        1628388,  201959,  204028, 1627752, 1628390,  203082, 1626179,
#         200757,  201152, 1628418, 1627748,  204025,  203501, 1627817,
#         202389, 1627789,  202699,  203107,    2754, 1628396,    2225,
#         203503, 1628470,  204037, 1626203,    2772,  202344,  203504,
#        1626168,  202684,  203584, 1627786, 1628463, 1628416,  203898,
#         204020, 1627755,  203092,  201936, 1627820,    2199, 1626145,
#           2617,  203505,  203506,    1713, 1626205, 1627735, 1627215,
#         201961, 1627782, 1628411,  202325,  202083,  203115, 1626161,
#         203186, 1626195,  201163,  204098, 1628504,  202918, 1627812,
#        1628380,  203897,    2216,    2585, 1627753])

# %%
df[df['Player_ID'] == 49]
# Out:
# Empty DataFrame
# Columns: [Year, Player_ID, X_loc, Y_loc]
# Index: []

# %%
df_finder = all_shots[all_shots['Player_ID'] == 203816]

# %%
df_finder[df_finder['Year'] == '2017-18']
# Out:
#             Year  Player_ID  X_loc  Y_loc
# 4206318  2017-18     203816     15     22

# %%
all_shots.reset_index(inplace=True, drop=True)

# %%
# import os, sys
# from PIL import Image

# for infile in os.listdir(path):
#     outfile = os.path.splitext(infile)[0] + ".png"
#     if infile != outfile:
#         try:
#             im = Image.open(infile)
#             im.crop((108, 95, 779, 694)).save(outfile, "PNG")
#             print(infile)
#         except IOError:
#             print("cannot create thumbnail for '%s'" % infile)
# Out:
# 383_1996-97.thumbnail
# 244_2001-02.thumbnail
# 101123_2017-18.thumbnail
# 203109_2012-13.thumbnail
# 1533_1999-00.thumbnail
# 2767_2007-08.thumbnail
# 203109_2014-15.thumbnail
# 201880_2013-14.thumbnail
# 1085_2000-01.thumbnail
# 1626162_2017-18.thumbnail
# 1628379_2017-18.thumbnail
# 101124_2011-12.thumbnail
# 202347_2013-14.thumbnail
# 959_2005-06.thumbnail
# 101249_2006-07.thumbnail
# 202809_2012-13.thumbnail
# 175_1997-98.thumbnail
# 202397_2013-14.thumbnail
# 270_1997-98.thumbnail
# 201584_2012-13.thumbnail
# 349_1999-00.thumbnail
# 1506_2000-01.thumbnail
# 2572_2009-10.thumbnail
# 2440_2014-15.thumbnail
# 202697_2016-17.thumbnail
# 200806_2006-07.thumbnail
# 1924_2001-02.thumbnail
# 203940_2014-15.thumbnail
# 399_1999-00.thumbnail
# 1506_2006-07.thumbnail
# 2440_2012-13.thumbnail
# 200749_2010-11.thumbnail
# 201584_2014-15.thumbnail
# 203117_2013-14.thumbnail
# 201976_2015-16.thumbnail
# 2216_2012-13.thumbnail
# 2043_2002-03.thumbnail
# 202389_2012-13.thumbnail
# 432_1998-99.thumbnail
# 202389_2014-15.thumbnail
# 2043_2004-05.thumbnail
# 2216_2014-15.thumbnail
# 426_1997-98.thumbnail
# 2549_2015-16.thumbnail
# 1628502_2017-18.thumbnail
# 1802_2009-10.thumbnail
# 2768_2012-13.thumbnail
# 2420_2010-11.thumbnail
# 2405_2005-06.thumbnail
# 1716_2001-02.thumbnail
# 101109_2011-12.thumbnail
# 1889_2011-12.thumbnail
# 2225_2013-14.thumbnail
# 1733_2012-13.thumbnail
# 381_2000-01.thumbnail
# 201567_2013-14.thumbnail
# 202339_2010-11.thumbnail
# 1711_2007-08.thumbnail
# 203505_2017-18.thumbnail
# 203124_2012-13.thumbnail
# 1628384_2017-18.thumbnail
# 1627773_2016-17.thumbnail
# 203124_2014-15.thumbnail
# 203469_2013-14.thumbnail
# 2072_2002-03.thumbnail
# 202339_2016-17.thumbnail
# 204001_2016-17.thumbnail
# 224_2005-06.thumbnail
# 203138_2014-15.thumbnail
# 200081_2009-10.thumbnail
# 1736_1998-99.thumbnail
# 905_1998-99.thumbnail
# 101112_2017-18.thumbnail
# 911_1997-98.thumbnail
# 201188_2017-18.thumbnail
# 364_1999-00.thumbnail
# 202703_2015-16.thumbnail
# 2585_2015-16.thumbnail
# 1627883_2017-18.thumbnail
# 201951_2009-10.thumbnail
# 201579_2014-15.thumbnail
# 2570_2006-07.thumbnail
# 2555_2015-16.thumbnail
# 203477_2014-15.thumbnail
# 1909_2001-02.thumbnail
# 1627853_2017-18.thumbnail
# 101161_2006-07.thumbnail
# 201579_2012-13.thumbnail
# 201158_2017-18.thumbnail
# 203086_2017-18.thumbnail
# 299_1998-99.thumbnail
# 200764_2010-11.thumbnail
# 201981_2009-10.thumbnail
# 202708_2016-17.thumbnail
# 201980_2016-17.thumbnail
# 203515_2014-15.thumbnail
# 760_2000-01.thumbnail
# 688_2001-02.thumbnail
# 1499_2000-01.thumbnail
# 203088_2013-14.thumbnail
# 1499_2006-07.thumbnail
# 200765_2009-10.thumbnail
# 203937_2015-16.thumbnail
# 201156_2013-14.thumbnail
# 2217_2003-04.thumbnail
# 49_1999-00.thumbnail
# 2441_2003-04.thumbnail
# 101128_2008-09.thumbnail
# 136_2006-07.thumbnail
# 1129_1996-97.thumbnail
# cannot create thumbnail for '.DS_Store'
# 1900_2003-04.thumbnail
# 136_2000-01.thumbnail
# 2034_2005-06.thumbnail
# 2294_2006-07.thumbnail
# 105_1996-97.thumbnail
# 203096_2012-13.thumbnail
# 201148_2012-13.thumbnail
# 2209_2002-03.thumbnail
# 201569_2017-18.thumbnail
# 785_1999-00.thumbnail
# 1545_1997-98.thumbnail
# 201148_2014-15.thumbnail
# 956_1999-00.thumbnail
# 2209_2004-05.thumbnail
# 203096_2014-15.thumbnail
# 436_2003-04.thumbnail
# 103_1999-00.thumbnail
# 2738_2009-10.thumbnail
# 200779_2009-10.thumbnail
# 2592_2010-11.thumbnail
# 323_1997-98.thumbnail
# 708_2011-12.thumbnail
# 783_1996-97.thumbnail
# 200756_2006-07.thumbnail
# 980_2009-10.thumbnail
# 950_1996-97.thumbnail
# 2592_2016-17.thumbnail
# 200786_2006-07.thumbnail
# 753_1996-97.thumbnail
# 694_2001-02.thumbnail
# 2567_2005-06.thumbnail
# 64_1999-00.thumbnail
# 2246_2009-10.thumbnail
# 2351_2001-02.thumbnail
# 283_2002-03.thumbnail
# 101111_2007-08.thumbnail
# 2048_2001-02.thumbnail
# 1627823_2016-17.thumbnail
# 1754_1999-00.thumbnail
# 1891_2007-08.thumbnail
# 699_1998-99.thumbnail
# 283_2004-05.thumbnail
# 1885_2008-09.thumbnail
# 281_2003-04.thumbnail
# 961_1996-97.thumbnail
# 201242_2007-08.thumbnail
# 101133_2014-15.thumbnail
# 1628021_2016-17.thumbnail
# 101133_2012-13.thumbnail
# 101236_2012-13.thumbnail
# 1761_2000-01.thumbnail
# 467_2009-10.thumbnail
# 201601_2009-10.thumbnail
# 2457_2011-12.thumbnail
# 448_2006-07.thumbnail
# 201961_2016-17.thumbnail
# 952_2006-07.thumbnail
# 952_2000-01.thumbnail
# 448_2000-01.thumbnail
# 977_2015-16.thumbnail
# 201961_2010-11.thumbnail
# 201593_2011-12.thumbnail
# 51_2000-01.thumbnail
# 201153_2008-09.thumbnail
# 201147_2007-08.thumbnail
# 2047_2008-09.thumbnail
# 1761_2006-07.thumbnail
# 101236_2014-15.thumbnail
# 685_1998-99.thumbnail
# 2224_2002-03.thumbnail
# 2605_2007-08.thumbnail
# 2201_2011-12.thumbnail
# 2224_2004-05.thumbnail
# 2054_2001-02.thumbnail
# 2199_2015-16.thumbnail
# 763_2000-01.thumbnail
# 203516_2014-15.thumbnail
# 202412_2016-17.thumbnail
# 201953_2010-11.thumbnail
# 203934_2015-16.thumbnail
# 201155_2013-14.thumbnail
# 2214_2003-04.thumbnail
# 2694_2010-11.thumbnail
# 2411_2006-07.thumbnail
# 328_1998-99.thumbnail
# 673_1997-98.thumbnail
# 2617_2013-14.thumbnail
# 203962_2017-18.thumbnail
# 949_1999-00.thumbnail
# 2037_2005-06.thumbnail
# 203_1996-97.thumbnail
# 1903_2003-04.thumbnail
# 1965_1999-00.thumbnail
# 201203_2010-11.thumbnail
# 203508_2013-14.thumbnail
# 203095_2012-13.thumbnail
# 203095_2014-15.thumbnail
# 56_1999-00.thumbnail
# 203464_2017-18.thumbnail
# 200755_2006-07.thumbnail
# 1479_1996-97.thumbnail
# 100_1999-00.thumbnail
# 101150_2010-11.thumbnail
# 201169_2007-08.thumbnail
# 1628463_2017-18.thumbnail
# 101150_2016-17.thumbnail
# 1938_2011-12.thumbnail
# 2564_2005-06.thumbnail
# 200770_2015-16.thumbnail
# 202536_2011-12.thumbnail
# 101112_2007-08.thumbnail
# 339_2001-02.thumbnail
# 204038_2015-16.thumbnail
# 67_1999-00.thumbnail
# 2352_2001-02.thumbnail
# 964_1999-00.thumbnail
# 101106_2008-09.thumbnail
# 203539_2013-14.thumbnail
# 1952_2009-10.thumbnail
# 2419_2015-16.thumbnail
# 406_2002-03.thumbnail
# 962_1996-97.thumbnail
# 203076_2013-14.thumbnail
# 61_1996-97.thumbnail
# 101130_2012-13.thumbnail
# 228_1999-00.thumbnail
# 200764_2006-07.thumbnail
# 203919_2015-16.thumbnail
# 2239_2003-04.thumbnail
# 1895_2001-02.thumbnail
# 406_2004-05.thumbnail
# 2774_2004-05.thumbnail
# 1733_2002-03.thumbnail
# 201602_2009-10.thumbnail
# 703_2004-05.thumbnail
# 201962_2016-17.thumbnail
# 200778_2006-07.thumbnail
# 951_2006-07.thumbnail
# 2739_2006-07.thumbnail
# 201180_2008-09.thumbnail
# 101158_2005-06.thumbnail
# 200757_2009-10.thumbnail
# 201144_2007-08.thumbnail
# 2853_2005-06.thumbnail
# 202683_2015-16.thumbnail
# 201933_2012-13.thumbnail
# 2549_2005-06.thumbnail
# 951_2000-01.thumbnail
# 101188_2005-06.thumbnail
# 201962_2010-11.thumbnail
# 201590_2011-12.thumbnail
# 703_2002-03.thumbnail
# 2050_2007-08.thumbnail
# 2471_2002-03.thumbnail
# 201150_2008-09.thumbnail
# 201166_2012-13.thumbnail
# 692_1997-98.thumbnail
# 1731_2003-04.thumbnail
# 185_2004-05.thumbnail
# 203499_2017-18.thumbnail
# 686_1998-99.thumbnail
# 2057_2001-02.thumbnail
# 902_2003-04.thumbnail
# 1134_2000-01.thumbnail
# 185_2002-03.thumbnail
# 203953_2017-18.thumbnail
# 2202_2011-12.thumbnail
# 201166_2014-15.thumbnail
# 203497_2013-14.thumbnail
# 201274_2011-12.thumbnail
# 1626161_2017-18.thumbnail
# 201599_2013-14.thumbnail
# 297_2001-02.thumbnail
# 1738_2001-02.thumbnail
# 101127_2011-12.thumbnail
# 202344_2013-14.thumbnail
# 1882_2002-03.thumbnail
# 2746_2012-13.thumbnail
# 1548_2004-05.thumbnail
# 1548_2002-03.thumbnail
# 2746_2014-15.thumbnail
# 201938_2011-12.thumbnail
# 1600_2000-01.thumbnail
# 1882_2004-05.thumbnail
# 202694_2016-17.thumbnail
# 203078_2017-18.thumbnail
# 201587_2012-13.thumbnail
# 273_1997-98.thumbnail
# 202091_2013-14.thumbnail
# 203489_2014-15.thumbnail
# 1505_2000-01.thumbnail
# 714_2001-02.thumbnail
# 2571_2009-10.thumbnail
# 2223_2008-09.thumbnail
# 201587_2014-15.thumbnail
# 203114_2013-14.thumbnail
# 201975_2015-16.thumbnail
# 203459_2014-15.thumbnail
# 203943_2014-15.thumbnail
# 2040_2002-03.thumbnail
# 363_2000-01.thumbnail
# 2215_2012-13.thumbnail
# 1718_1998-99.thumbnail
# 201171_2011-12.thumbnail
# 2230_2001-02.thumbnail
# 431_1998-99.thumbnail
# 1065_1996-97.thumbnail
# 28_1998-99.thumbnail
# 2040_2004-05.thumbnail
# 1715_2001-02.thumbnail
# 203923_2016-17.thumbnail
# 203468_2014-15.thumbnail
# 1565_2004-05.thumbnail
# 201566_2012-13.thumbnail
# 2406_2005-06.thumbnail
# 1565_2002-03.thumbnail
# 2073_2003-04.thumbnail
# 203506_2017-18.thumbnail
# 1628387_2017-18.thumbnail
# 1627770_2016-17.thumbnail
# 201580_2008-09.thumbnail
# 201564_2013-14.thumbnail
# 2199_2005-06.thumbnail
# 1712_2007-08.thumbnail
# 2250_2005-06.thumbnail
# 204002_2016-17.thumbnail
# 2749_2007-08.thumbnail
# 682_2003-04.thumbnail
# 361_1996-97.thumbnail
# 1735_1998-99.thumbnail
# 906_1998-99.thumbnail
# 2048_2011-12.thumbnail
# 201952_2009-10.thumbnail
# 201988_2015-16.thumbnail
# 739_2001-02.thumbnail
# 203085_2017-18.thumbnail
# 1709_2001-02.thumbnail
# 203139_2013-14.thumbnail
# 1627850_2017-18.thumbnail
# 201632_2010-11.thumbnail
# 1863_2004-05.thumbnail
# 2648_2004-05.thumbnail
# 1891_2006-07.thumbnail
# 239_1998-99.thumbnail
# 672_2000-01.thumbnail
# 1891_2000-01.thumbnail
# 1627823_2017-18.thumbnail
# 1626175_2015-16.thumbnail
# 101111_2006-07.thumbnail
# 1110_1998-99.thumbnail
# 2770_2005-06.thumbnail
# 2755_2010-11.thumbnail
# 200797_2013-14.thumbnail
# 1628021_2017-18.thumbnail
# 1508_2003-04.thumbnail
# 76_1998-99.thumbnail
# 202699_2013-14.thumbnail
# 2553_2003-04.thumbnail
# 961_1997-98.thumbnail
# 219_2001-02.thumbnail
# 202349_2010-11.thumbnail
# 1761_2007-08.thumbnail
# 2403_2013-14.thumbnail
# 201961_2017-18.thumbnail
# 448_2007-08.thumbnail
# 697_1999-00.thumbnail
# 952_2007-08.thumbnail
# 202399_2010-11.thumbnail
# 2053_2000-01.thumbnail
# 201162_2015-16.thumbnail
# 2223_2005-06.thumbnail
# 202349_2016-17.thumbnail
# 101179_2011-12.thumbnail
# 202687_2012-13.thumbnail
# 202687_2014-15.thumbnail
# 2568_2011-12.thumbnail
# 2857_2004-05.thumbnail
# 691_1996-97.thumbnail
# 200789_2012-13.thumbnail
# 2605_2006-07.thumbnail
# 56_2001-02.thumbnail
# 128_1997-98.thumbnail
# 955_2001-02.thumbnail
# 202329_2014-15.thumbnail
# 988_1998-99.thumbnail
# 2406_2008-09.thumbnail
# 2033_2002-03.thumbnail
# 958_1998-99.thumbnail
# 2033_2004-05.thumbnail
# 2243_2001-02.thumbnail
# 202329_2012-13.thumbnail
# 456_1997-98.thumbnail
# 339_1999-00.thumbnail
# 2294_2007-08.thumbnail
# 203512_2015-16.thumbnail
# 2430_2014-15.thumbnail
# 200768_2014-15.thumbnail
# 203930_2014-15.thumbnail
# 1626158_2015-16.thumbnail
# 136_2007-08.thumbnail
# 2250_2008-09.thumbnail
# 2430_2012-13.thumbnail
# 201575_2010-11.thumbnail
# 2735_2012-13.thumbnail
# 201569_2010-11.thumbnail
# 101154_2011-12.thumbnail
# 693_2006-07.thumbnail
# 202337_2013-14.thumbnail
# 2560_2004-05.thumbnail
# 1919_2005-06.thumbnail
# 2545_2011-12.thumbnail
# 111_1998-99.thumbnail
# 201569_2016-17.thumbnail
# 105_1997-98.thumbnail
# 978_2001-02.thumbnail
# 753_1997-98.thumbnail
# 1889_1999-00.thumbnail
# 201145_2009-10.thumbnail
# 200756_2007-08.thumbnail
# 2254_2002-03.thumbnail
# 2399_2016-17.thumbnail
# 1518_1997-98.thumbnail
# 1742_2003-04.thumbnail
# 386_2001-02.thumbnail
# 203920_2017-18.thumbnail
# 2399_2010-11.thumbnail
# 2254_2004-05.thumbnail
# 203123_2015-16.thumbnail
# 201942_2013-14.thumbnail
# 708_1999-00.thumbnail
# 72_2003-04.thumbnail
# 202339_2017-18.thumbnail
# 202718_2012-13.thumbnail
# 204001_2017-18.thumbnail
# 1711_2000-01.thumbnail
# 1740_2002-03.thumbnail
# 2402_2004-05.thumbnail
# 2427_2011-12.thumbnail
# 203584_2014-15.thumbnail
# 124_2003-04.thumbnail
# 922_2000-01.thumbnail
# 21_2000-01.thumbnail
# 2402_2002-03.thumbnail
# 1711_2006-07.thumbnail
# 2037_2008-09.thumbnail
# 202718_2014-15.thumbnail
# 911_1996-97.thumbnail
# 200809_2012-13.thumbnail
# 201574_2009-10.thumbnail
# 101112_2010-11.thumbnail
# 376_1998-99.thumbnail
# 2756_2006-07.thumbnail
# 201188_2010-11.thumbnail
# 1497_2003-04.thumbnail
# 203086_2016-17.thumbnail
# 101161_2007-08.thumbnail
# 201158_2016-17.thumbnail
# 2570_2007-08.thumbnail
# 1724_1999-00.thumbnail
# 201158_2010-11.thumbnail
# 202706_2013-14.thumbnail
# 2669_2007-08.thumbnail
# 201188_2016-17.thumbnail
# 2564_2008-09.thumbnail
# 2736_2004-05.thumbnail
# 2748_2009-10.thumbnail
# 1626162_2016-17.thumbnail
# 101106_2005-06.thumbnail
# 2767_2006-07.thumbnail
# 1713_2009-10.thumbnail
# 1425_2006-07.thumbnail
# 101123_2016-17.thumbnail
# 1886_2005-06.thumbnail
# 1521_1998-99.thumbnail
# 175_1996-97.thumbnail
# 1535_1997-98.thumbnail
# 1916_1999-00.thumbnail
# 243_2000-01.thumbnail
# 2207_2009-10.thumbnail
# 243_2006-07.thumbnail
# 2561_2013-14.thumbnail
# 446_2003-04.thumbnail
# 1506_2007-08.thumbnail
# 739_1999-00.thumbnail
# 202697_2017-18.thumbnail
# 1709_1999-00.thumbnail
# 201175_2010-11.thumbnail
# 146_2000-01.thumbnail
# 270_1996-97.thumbnail
# 2549_2008-09.thumbnail
# 201589_2009-10.thumbnail
# 203565_2014-15.thumbnail
# 1501_2001-02.thumbnail
# 458_2002-03.thumbnail
# 201971_2012-13.thumbnail
# 458_2004-05.thumbnail
# 201971_2014-15.thumbnail
# 201583_2015-16.thumbnail
# 202690_2011-12.thumbnail
# 3_2001-02.thumbnail
# 201941_2013-14.thumbnail
# 468_2003-04.thumbnail
# 203923_2017-18.thumbnail
# 2401_2004-05.thumbnail
# 2749_2006-07.thumbnail
# 970_2004-05.thumbnail
# 1712_2000-01.thumbnail
# 1737_2015-16.thumbnail
# 101128_2005-06.thumbnail
# 1712_2006-07.thumbnail
# 2034_2008-09.thumbnail
# 2823_2005-06.thumbnail
# 1627770_2017-18.thumbnail
# 203506_2016-17.thumbnail
# 2401_2002-03.thumbnail
# 2605_2010-11.thumbnail
# 1922_2009-10.thumbnail
# 2581_2014-15.thumbnail
# 288_1999-00.thumbnail
# 912_1996-97.thumbnail
# 361_1997-98.thumbnail
# 258_1999-00.thumbnail
# 2249_2003-04.thumbnail
# 711_2009-10.thumbnail
# 203473_2015-16.thumbnail
# 201577_2009-10.thumbnail
# 2581_2012-13.thumbnail
# 375_1998-99.thumbnail
# 101162_2007-08.thumbnail
# 1627850_2016-17.thumbnail
# 203085_2016-17.thumbnail
# 914_1999-00.thumbnail
# 204098_2015-16.thumbnail
# 2567_2008-09.thumbnail
# 1727_1999-00.thumbnail
# 202705_2013-14.thumbnail
# 168_2000-01.thumbnail
# 693_2010-11.thumbnail
# 170_1999-00.thumbnail
# 1477_2002-03.thumbnail
# 213_2003-04.thumbnail
# 101120_2010-11.thumbnail
# 1626161_2016-17.thumbnail
# 1885_2005-06.thumbnail
# 1477_2004-05.thumbnail
# 1710_2009-10.thumbnail
# 923_1996-97.thumbnail
# 1607_2001-02.thumbnail
# 1915_1999-00.thumbnail
# 1051_2001-02.thumbnail
# 1522_1998-99.thumbnail
# 1838_1998-99.thumbnail
# 176_1996-97.thumbnail
# 445_2003-04.thumbnail
# 200839_2013-14.thumbnail
# 203111_2015-16.thumbnail
# 423_1999-00.thumbnail
# 2047_2005-06.thumbnail
# 273_1996-97.thumbnail
# 200811_2008-09.thumbnail
# 203078_2016-17.thumbnail
# 202694_2017-18.thumbnail
# 145_2000-01.thumbnail
# 713_2000-01.thumbnail
# 1502_2001-02.thumbnail
# 203994_2015-16.thumbnail
# 42_2002-03.thumbnail
# 1065_1997-98.thumbnail
# 275_1999-00.thumbnail
# 202693_2011-12.thumbnail
# 203944_2015-16.thumbnail
# 201580_2015-16.thumbnail
# 2757_2009-10.thumbnail
# 358_1998-99.thumbnail
# 2756_2016-17.thumbnail
# 317_1999-00.thumbnail
# 2306_2003-04.thumbnail
# 1495_2014-15.thumbnail
# 1495_2012-13.thumbnail
# 2756_2010-11.thumbnail
# 202721_2011-12.thumbnail
# 1892_2000-01.thumbnail
# 1627820_2017-18.thumbnail
# 1626176_2015-16.thumbnail
# 101112_2006-07.thumbnail
# 2580_2003-04.thumbnail
# 200794_2013-14.thumbnail
# 1745_1998-99.thumbnail
# 2248_2012-13.thumbnail
# 2550_2003-04.thumbnail
# 61_1997-98.thumbnail
# 962_1997-98.thumbnail
# 201177_2009-10.thumbnail
# 202356_2010-11.thumbnail
# 976_1998-99.thumbnail
# 2038_2011-12.thumbnail
# 2050_2006-07.thumbnail
# 769_1998-99.thumbnail
# 2400_2013-14.thumbnail
# 203187_2014-15.thumbnail
# 201229_2011-12.thumbnail
# 2420_2007-08.thumbnail
# 202130_2009-10.thumbnail
# 2205_2010-11.thumbnail
# 203187_2012-13.thumbnail
# 694_1999-00.thumbnail
# 951_2007-08.thumbnail
#  '202083_2014-15.png',
#  '93_1996-97.png',
#  '2570_2012-13.png',
#  '1730_2006-07.png',
#  '703_2010-11.png',
#  '203901_2016-17.png',
#  '201600_2012-13.png',
#  '2209_2010-11.png',
#  '2205_2002-03.png',
#  '1519_2004-05.png',
#  '202335_2016-17.png',
#  '2443_2006-07.png',
#  '1500_1998-99.png',
#  '203527_2016-17.png',
#  '1800_2002-03.png',
#  '203077_2016-17.png',
#  '202355_2014-15.png',
#  '2735_2007-08.png',
#  '203482_2015-16.png',
#  '201950_2014-15.png',
#  '101111_2014-15.png',
#  '101127_2005-06.png',
#  '101124_2008-09.png',
#  '1628388_2017-18.png',
#  '203115_2016-17.png',
#  '2048_2008-09.png',
#  '201586_2009-10.png',
#  '203203_2012-13.png',
#  '1891_2012-13.png',
#  '200796_2010-11.png',
#  '1902_2007-08.png',
#  '1710_2003-04.png',
#  '201149_2009-10.png',
#  '2484_2005-06.png',
#  '708_2005-06.png',
#  '1627752_2017-18.png',
#  '201041_2011-12.png',
#  '1737_2001-02.png',
#  '2239_2009-10.png',
#  '384_1998-99.png',
#  '1902_2000-01.png',
#  '258_2005-06.png',
#  '2581_2007-08.png',
#  '201144_2014-15.png',
#  '201171_2008-09.png',
#  '2590_2013-14.png',
#  '200763_2008-09.png',
#  '202332_2011-12.png',
#  '57_1998-99.png',
#  '1074_2000-01.png',
#  '2768_2006-07.png',
#  '2752_2005-06.png',
#  '203507_2013-14.png',
#  '201937_2011-12.png',
#  '2202_2005-06.png',
#  '707_1999-00.png',
#  '1564_1997-98.png',
#  '1544_2002-03.png',
#  '201208_2011-12.png',
#  '101236_2006-07.png',
#  '1559_2003-04.png',
#  '203498_2013-14.png',
#  '980_2003-04.png',
#  '179_1996-97.png',
#  '2030_2010-11.png',
#  '203158_2012-13.png',
#  '1916_2008-09.png',
#  '1720_2004-05.png',
#  '2571_2003-04.png',
#  '202880_2011-12.png',
#  '1626157_2015-16.png',
#  '1739_1998-99.png',
#  '203145_2013-14.png',
#  '345_1999-00.png',
#  '1497_2009-10.png',
#  '2199_2001-02.png',
#  ...]

# %%
import numpy as np

players = np.array(['177', '292', '320', '461', '712', '728', '955', '988', '1037', '1085', '1541', '1682', '1820', '2078', '2098', '2121', '2130', '2237', '2429', '2441', '2442', '2583', '2669', '2750', '2767', '2866', '101113', '101213', '101236', '201173', '202330', '202726', '202933', '203203', '203479', '204021', '1626643', '1627851', '1627852', '2199', '731', '280', '201', '712', '2730', '2071', '989', '203497', '31', '203991', '1942', '201599', '1905', '1096', '2038', '200767', '1985', '2198', '201599', '88', '203991', '1727', '2199', '201600', '781', '201600', '101133', '1751', '1751', '1751', '202962', '203474', '2429', '203083', '202962', '406', '2038', '1513', '781', '2740', '1112', '2501', '203108', '2201', '202354', '201595', '2038', '1628493', '940', '1504', '1112', '1627856', '2199', '203991', '1529', '781', '201599', '203139', '998', '201600', '692', '200822', '2201', '956', '2740', '201595', '2199', '956', '1112', '262', '201599', '238', '203497', '101236', '2038', '1035', '2740', '2199', '201178', '1043', '246', '781', '1913', '